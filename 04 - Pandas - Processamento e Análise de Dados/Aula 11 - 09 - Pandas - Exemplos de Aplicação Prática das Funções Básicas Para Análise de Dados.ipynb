# %% [markdown]
# # 04 - Pandas - Processamento e Análise de Dados
# ## Aula 11 - 09 - Pandas - Exemplos de Aplicação Prática das Funções Básicas Para Análise de Dados

# %% [markdown]
# ## Professor: Orlando Oliveira dos Santos, MsC.
#  - E-mail: professor.orlando.santos@gmail.com
#  - Youtube :https://www.youtube.com/channel/UCPWWbkPWFmOjXH50TQWNAYg
#  - Linkedin: https://linkedin.com/in/orlandoosantos
#  - Facebook: https://www.facebook.com/proforlandosantosmsc/
#  - Twitter: https://twitter.com/ProfOrlandoMsC
#  - Instagram: https://www.instagram.com/proforlandosantosmsc/
#
#
#
# ## Formação Acadêmica
# - Mestrado em Computação Aplicada - UnB (2014 – 2016)
# - MBA, Administração Estratégica de Sistemas de Informação – FGV (2011 – 2013)
# - Tecnólogo em Processamento de Dados, Análise e Desenvolvimento de Sistemas – FAETEC/SP (2000-2002)

# %% [markdown]
# # Pandas - Exemplos de Aplicação Prática das Funções Básicas Para Análise de Dados
# ## Pandas
#
# O pandas é uma ferramenta de análise e manipulação de dados de código aberto rápida, poderosa, flexível e fácil de usar,
# construída sobre a linguagem de programação Python
#
# https://pandas.pydata.org/

# %% [markdown]
# # Aplicando os conceitos aprendidos

# %%
import numpy as np
import pandas as pd
import os
import zipfile

diratual = os.getcwd()
print(diratual)

diretorio = os.path.join(diratual, 'content') 
diretorio


nome_arquivo_compactado = 'HIST_PAINEL_COVIDBR_18nov2020.zip'
with zipfile.ZipFile( os.path.join(diretorio, nome_arquivo_compactado), 'r') as zip_ref:
    zip_ref.extractall(diretorio)
# Out:
# C:\Orlando\Curso-de-Python-Para-Analise-de-Dados\04 - Pandas - Processamento e Análise de Dados

# %%
import pandas as pd
dfcovid = pd.read_csv('./content/HIST_PAINEL_COVIDBR_18nov2020.csv', sep=';')
dfcovid.head()
# Out:
#    regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
#          data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 0  2020-02-25          9       210147125.0               0           0
# 1  2020-02-26          9       210147125.0               1           1
# 2  2020-02-27          9       210147125.0               1           0
# 3  2020-02-28          9       210147125.0               1           0
# 4  2020-02-29          9       210147125.0               2           1
#
#    obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos  \
# 0                0            0               NaN                    NaN
# 1                0            0               NaN                    NaN
# 2                0            0               NaN                    NaN
# 3                0            0               NaN                    NaN
# 4                0            0               NaN                    NaN
#
#    interior/metropolitana
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %%
dfcovid.columns
# Out:
# Index(['regiao', 'estado', 'municipio', 'coduf', 'codmun', 'codRegiaoSaude',
#        'nomeRegiaoSaude', 'data', 'semanaEpi', 'populacaoTCU2019',
#        'casosAcumulado', 'casosNovos', 'obitosAcumulado', 'obitosNovos',
#        'Recuperadosnovos', 'emAcompanhamentoNovos', 'interior/metropolitana'],
#       dtype='object')

# %%
colunasselecionadas = ['regiao', 'estado', 'municipio', 'coduf', 'codmun', 'codRegiaoSaude',
       'nomeRegiaoSaude', 'data', 'semanaEpi', 'populacaoTCU2019', 'casosNovos',  'obitosNovos',
      ]

# %%
dfcovid = dfcovid [colunasselecionadas]

# %%
filtro = dfcovid['estado'].isna() == False
filtro.tail()
# Out:
# 1343804    True
# 1343805    True
# 1343806    True
# 1343807    True
# 1343808    True
# Name: estado, dtype: bool

# %%
dfcovid[filtro].head()
# Out:
#     regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 270  Norte     RO       NaN     11     NaN             NaN             NaN
# 271  Norte     RO       NaN     11     NaN             NaN             NaN
# 272  Norte     RO       NaN     11     NaN             NaN             NaN
# 273  Norte     RO       NaN     11     NaN             NaN             NaN
# 274  Norte     RO       NaN     11     NaN             NaN             NaN
#
#            data  semanaEpi  populacaoTCU2019  casosNovos  obitosNovos
# 270  2020-02-25          9         1777225.0           0            0
# 271  2020-02-26          9         1777225.0           0            0
# 272  2020-02-27          9         1777225.0           0            0
# 273  2020-02-28          9         1777225.0           0            0
# 274  2020-02-29          9         1777225.0           0            0

# %%
 dfcovid = dfcovid[ dfcovid['estado'].isna() == False ]

# %%
 dfcovid.head()
# Out:
#     regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 270  Norte     RO       NaN     11     NaN             NaN             NaN
# 271  Norte     RO       NaN     11     NaN             NaN             NaN
# 272  Norte     RO       NaN     11     NaN             NaN             NaN
# 273  Norte     RO       NaN     11     NaN             NaN             NaN
# 274  Norte     RO       NaN     11     NaN             NaN             NaN
#
#            data  semanaEpi  populacaoTCU2019  casosNovos  obitosNovos
# 270  2020-02-25          9         1777225.0           0            0
# 271  2020-02-26          9         1777225.0           0            0
# 272  2020-02-27          9         1777225.0           0            0
# 273  2020-02-28          9         1777225.0           0            0
# 274  2020-02-29          9         1777225.0           0            0

# %%
dfcovid.tail()
# Out:
#                regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 1343804  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1343805  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1343806  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1343807  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1343808  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#           nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 1343804  DISTRITO FEDERAL  2020-11-16         47         3015268.0
# 1343805  DISTRITO FEDERAL  2020-11-17         47         3015268.0
# 1343806  DISTRITO FEDERAL  2020-11-18         47         3015268.0
# 1343807  DISTRITO FEDERAL  2020-11-19         47         3015268.0
# 1343808  DISTRITO FEDERAL  2020-11-20         47         3015268.0
#
#          casosNovos  obitosNovos
# 1343804         411            8
# 1343805         628           12
# 1343806         495            8
# 1343807         756            7
# 1343808         554            5

# %%
dfcovid = dfcovid[ dfcovid['codmun'].isna() ]
dfcovid.head()
# Out:
#     regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 270  Norte     RO       NaN     11     NaN             NaN             NaN
# 271  Norte     RO       NaN     11     NaN             NaN             NaN
# 272  Norte     RO       NaN     11     NaN             NaN             NaN
# 273  Norte     RO       NaN     11     NaN             NaN             NaN
# 274  Norte     RO       NaN     11     NaN             NaN             NaN
#
#            data  semanaEpi  populacaoTCU2019  casosNovos  obitosNovos
# 270  2020-02-25          9         1777225.0           0            0
# 271  2020-02-26          9         1777225.0           0            0
# 272  2020-02-27          9         1777225.0           0            0
# 273  2020-02-28          9         1777225.0           0            0
# 274  2020-02-29          9         1777225.0           0            0

# %%
dfcovid.tail()
# Out:
#             regiao estado municipio  coduf  codmun  codRegiaoSaude  \
# 7555  Centro-Oeste     DF       NaN     53     NaN             NaN
# 7556  Centro-Oeste     DF       NaN     53     NaN             NaN
# 7557  Centro-Oeste     DF       NaN     53     NaN             NaN
# 7558  Centro-Oeste     DF       NaN     53     NaN             NaN
# 7559  Centro-Oeste     DF       NaN     53     NaN             NaN
#
#      nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  casosNovos  \
# 7555             NaN  2020-11-16         47         3015268.0         411
# 7556             NaN  2020-11-17         47         3015268.0         628
# 7557             NaN  2020-11-18         47         3015268.0         495
# 7558             NaN  2020-11-19         47         3015268.0         756
# 7559             NaN  2020-11-20         47         3015268.0         554
#
#       obitosNovos
# 7555            8
# 7556           12
# 7557            8
# 7558            7
# 7559            5

# %%
dfcovid.columns
# Out:
# Index(['regiao', 'estado', 'municipio', 'coduf', 'codmun', 'codRegiaoSaude',
#        'nomeRegiaoSaude', 'data', 'semanaEpi', 'populacaoTCU2019',
#        'casosNovos', 'obitosNovos'],
#       dtype='object')

# %%
colunasselecionadas = ['regiao', 'estado',   'data', 'semanaEpi', 'populacaoTCU2019',
       'casosNovos', 'obitosNovos']
dfcovid = dfcovid[colunasselecionadas]
dfcovid.head()
# Out:
#     regiao estado        data  semanaEpi  populacaoTCU2019  casosNovos  \
# 270  Norte     RO  2020-02-25          9         1777225.0           0
# 271  Norte     RO  2020-02-26          9         1777225.0           0
# 272  Norte     RO  2020-02-27          9         1777225.0           0
# 273  Norte     RO  2020-02-28          9         1777225.0           0
# 274  Norte     RO  2020-02-29          9         1777225.0           0
#
#      obitosNovos
# 270            0
# 271            0
# 272            0
# 273            0
# 274            0

# %%
dfcovid[['casosNovos',	'obitosNovos']].describe()
# Out:
#          casosNovos  obitosNovos
# count   7290.000000  7290.000000
# mean     825.811248    23.129355
# std     1466.858685    45.990794
# min    -7926.000000   -75.000000
# 25%       66.000000     1.000000
# 50%      367.000000     8.000000
# 75%     1030.750000    24.000000
# max    30913.000000   713.000000

# %%
dfcovid[['regiao',	'estado']].describe()
# Out:
#           regiao estado
# count       7290   7290
# unique         5     27
# top     Nordeste     PA
# freq        2430    270

# %%
dfcovid[ (dfcovid.casosNovos < 0) | (dfcovid.obitosNovos < 0)]
# Out:
#             regiao estado        data  semanaEpi  populacaoTCU2019  \
# 956          Norte     AM  2020-07-20         30         4144597.0
# 976          Norte     AM  2020-08-09         33         4144597.0
# 1199         Norte     RR  2020-06-23         26          605761.0
# 1504         Norte     PA  2020-07-28         31         8602865.0
# 1505         Norte     PA  2020-07-29         31         8602865.0
# 1563         Norte     PA  2020-09-25         39         8602865.0
# 2893      Nordeste     CE  2020-09-05         36         9132078.0
# 2956      Nordeste     CE  2020-11-07         45         9132078.0
# 3139      Nordeste     RN  2020-08-12         33         3506853.0
# 3701      Nordeste     PE  2020-09-03         36         9557071.0
# 6894  Centro-Oeste     MT  2020-07-18         29         3484466.0
# 7165  Centro-Oeste     GO  2020-07-19         30         7018354.0
#
#       casosNovos  obitosNovos
# 956          476           -3
# 976          522           -5
# 1199        2152           -1
# 1504        1362          -13
# 1505        1664          -22
# 1563        1240          -75
# 2893       -7926           10
# 2956         698           -2
# 3139       -1349           16
# 3701        1475          -37
# 6894        -264           37
# 7165         -26           13

# %% [markdown]
# ## Qual total de casos e óbitos do Brasil?

# %%
totalbrasil = dfcovid[['casosNovos','obitosNovos']].sum()

# %%
totalbrasil = dfcovid[['casosNovos','obitosNovos']].agg('sum')

# %% [markdown]
# ## Qual o total por região?

# %%
totalregioes = dfcovid.groupby('regiao')[['casosNovos','obitosNovos']].sum()
totalregioes
# Out:
#               casosNovos  obitosNovos
# regiao
# Centro-Oeste      739895        15796
# Nordeste         1565933        43701
# Norte             745439        16496
# Sudeste          2107276        76906
# Sul               861621        15714

# %%
totalregioes = dfcovid.groupby('regiao', sort=True)[['casosNovos','obitosNovos']].agg('sum')
totalregioes
# Out:
#               casosNovos  obitosNovos
# regiao
# Centro-Oeste      739895        15796
# Nordeste         1565933        43701
# Norte             745439        16496
# Sudeste          2107276        76906
# Sul               861621        15714

# %%
totalregioes.sort_values(by= 'obitosNovos', ascending=False)
# Out:
#               casosNovos  obitosNovos
# regiao
# Sudeste          2107276        76906
# Nordeste         1565933        43701
# Norte             745439        16496
# Centro-Oeste      739895        15796
# Sul               861621        15714

# %% [markdown]
# Qual o total por estados

# %%
totalestados = dfcovid.groupby(['regiao','estado'])[['casosNovos','obitosNovos']].agg('sum')
totalestados.head(3)
# Out:
#                      casosNovos  obitosNovos
# regiao       estado
# Centro-Oeste DF          222836         3857
#              GO          272494         6201
#              MS           90765         1713

# %%
totalestados = dfcovid.groupby(['regiao','estado'])[['casosNovos','obitosNovos']].sum()
totalestados.head(3)
# Out:
#                      casosNovos  obitosNovos
# regiao       estado
# Centro-Oeste DF          222836         3857
#              GO          272494         6201
#              MS           90765         1713

# %%
totalestados.sort_values(by=['regiao','obitosNovos']).head()
# Out:
#                      casosNovos  obitosNovos
# regiao       estado
# Centro-Oeste MS           90765         1713
#              DF          222836         3857
#              MT          153800         4025
#              GO          272494         6201
# Nordeste     SE           86847         2274

# %%
totalestadoeregiao = totalestados

# %%
totalestadoeregiao.columns = ['casosNovosUF', 'obitosNovosUF']
totalestadoeregiao.reset_index(inplace=True)

# %%
novoestadoregiao = pd.merge(totalestadoeregiao, totalregioes, on='regiao')
novoestadoregiao.head()
# Out:
#          regiao estado  casosNovosUF  obitosNovosUF  casosNovos  obitosNovos
# 0  Centro-Oeste     DF        222836           3857      739895        15796
# 1  Centro-Oeste     GO        272494           6201      739895        15796
# 2  Centro-Oeste     MS         90765           1713      739895        15796
# 3  Centro-Oeste     MT        153800           4025      739895        15796
# 4      Nordeste     AL         93245           2311     1565933        43701

# %%
novoestadoregiao = novoestadoregiao.sort_values(by=['obitosNovos','regiao' ,'obitosNovosUF' ] , ascending=False)\
                  [['regiao',	'estado','casosNovosUF',	'obitosNovosUF']]

# %%
novoestadoregiao.head()
# Out:
#       regiao estado  casosNovosUF  obitosNovosUF
# 23   Sudeste     SP       1200348          41179
# 22   Sudeste     RJ        336915          21938
# 21   Sudeste     MG        393110           9688
# 20   Sudeste     ES        176903           4101
# 6   Nordeste     CE        289925           9477

# %%
novoestadoregiao.groupby(['regiao',	'estado']).sum()
# Out:
#                      casosNovosUF  obitosNovosUF
# regiao       estado
# Centro-Oeste DF            222836           3857
#              GO            272494           6201
#              MS             90765           1713
#              MT            153800           4025
# Nordeste     AL             93245           2311
#              BA            382164           8061
#              CE            289925           9477
#              MA            190953           4218
#              PB            141615           3236
#              PE            174312           8899
#              PI            122007           2568
#              RN             84865           2657
#              SE             86847           2274
# Norte        AC             34246            711
#              AM            172858           4761
#              AP             56085            787
#              PA            264810           6855
#              RO             76729           1515
#              RR             61553            720
#              TO             79158           1147
# Sudeste      ES            176903           4101
#              MG            393110           9688
#              RJ            336915          21938
#              SP           1200348          41179
# Sul          PR            250898           5832
#              RS            293221           6447
#              SC            317502           3435

# %% [markdown]
# ## Leituras Adicionais e Referências:
#
# - Python Tutorial at W3Schools: https://www.w3schools.com/python/
# - Python official documentation: https://docs.python.org/3/tutorial/index.html
# - Pandas  official documentation: https://pandas.pydata.org/pandas-docs/stable/index.html
