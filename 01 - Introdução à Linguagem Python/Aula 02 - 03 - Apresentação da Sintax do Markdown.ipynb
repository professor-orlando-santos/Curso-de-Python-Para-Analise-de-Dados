# %% [markdown]
# # 01 - Introdução à Linguagem Python
# ## Aula 02 - 03 - Apresentação da Sintax do Markdown

# %% [markdown]
# ## Professor: Orlando Oliveira dos Santos, MsC.
#  - E-mail: professor.orlando.santos@gmail.com
#  - Youtube :https://www.youtube.com/channel/UCPWWbkPWFmOjXH50TQWNAYg
#  - Linkedin: https://linkedin.com/in/orlandoosantos
#  - Facebook: https://www.facebook.com/proforlandosantosmsc/
#  - Twitter: https://twitter.com/ProfOrlandoMsC
#  - Instagram: https://www.instagram.com/proforlandosantosmsc/
#
#
#
# ## Formação Acadêmica
# - Mestrado em Computação Aplicada - UnB (2014 – 2016)
# - MBA, Administração Estratégica de Sistemas de Informação – FGV (2011 – 2013)
# - Tecnólogo em Processamento de Dados, Análise e Desenvolvimento de Sistemas – FAETEC/SP (2000-2002)

# %% [markdown]
# # Apresentação da Sintax do Markdown utilizado nas células de tipo texto
# Item | Sintáxe
# ---------| --------
# Títulos | Para criar um título, adicione sinais numéricos ( #) na frente de uma palavra ou frase. O número de sinais numéricos que você usa deve corresponder ao nível do título. Por exemplo, para criar um nível de título três, use três sinais de número
# Parágrafos | Para criar parágrafos, use uma linha em branco para separar uma ou mais linhas de texto.
# Quebras de linha | Para criar uma quebra de linha, termine uma linha com dois ou mais espaços e digite enter.
# Ênfase | Você pode adicionar ênfase colocando o texto em negrito ou itálico.
# Negrito | Para texto em negrito, adicione dois asteriscos ou sublinhados antes e depois de uma palavra ou frase. Para colocar em negrito o meio de uma palavra para dar ênfase, adicione dois asteriscos sem espaços ao redor das letras.
# itálico | Para colocar o texto em itálico, adicione um asterisco ou sublinhado antes e depois de uma palavra ou frase. Para colocar em itálico o meio de uma palavra para dar ênfase, adicione um asterisco sem espaços ao redor das letras.
# Negrito e Itálico | Para enfatizar o texto com negrito e itálico ao mesmo tempo, adicione três asteriscos ou sublinhados antes e depois de uma palavra ou frase. Para colocar em negrito e itálico no meio de uma palavra para dar ênfase, adicione três asteriscos sem espaços ao redor das letras.
# Citações em bloco | Para criar um blockquote, adicione um >na frente de um parágrafo.
# Citações com vários parágrafos | Citações podem conter vários parágrafos. Adicione um >nas linhas em branco entre os parágrafos.
# Listas | Você pode organizar itens em listas ordenadas e não ordenadas.
# Listas Ordenadas | Para criar uma lista ordenada, adicione itens de linha com números seguidos de pontos. Os números não precisam estar em ordem numérica, mas a lista deve começar com o número um.
# Listas não ordenadas | Para criar uma lista não ordenada, adicione travessões ( -), asteriscos ( *) ou sinais de adição ( +) na frente dos itens de linha. Recue um ou mais itens para criar uma lista aninhada.
# Regras horizontais | Para criar uma régua horizontal, use três ou mais asteriscos ( ***), traços ( ---) ou sublinhados ( ___) em uma linha.
# Links | Links para endereços Web podem ser inseridos com \[texto\](urllink):
# Imagens | Para inserir uma imagem, a sintaxe é a mesma de inserir um link, mas com uma exclamação (!) na frente: !\[texto\](urlimagem).
# Tabelas | Para adicionar uma tabela, use três ou mais hífens ( ---) para criar o cabeçalho de cada coluna e use barras verticais (|) para separar cada coluna. Opcionalmente, você pode adicionar | em qualquer extremidade da tabela.
# Alinhamento | Você pode alinhar o texto nas colunas à esquerda, à direita ou ao centro adicionando dois-pontos ( :) à esquerda, à direita ou em ambos os lados dos hifens na linha do cabeçalho.
# Listas de tarefas | Para criar uma lista de tarefas, prefacie os itens da lista com um caractere de espaço regular seguido por [ ]. Para marcar uma tarefa como concluída, use [x].

# %% [markdown]
# ## Títulos
#
# ```
# # Título de nível 1
# ## Título de nível 2
# ### Título de nível 3
# #### Nível 4 do título
# ##### Nível 5 do título
# ###### Nível 6 do título
# ```
#
# # Título de nível 1
# ## Título de nível 2
# ### Título de nível 3
# #### Nível 4 do título
# ##### Nível 5 do título
# ###### Nível 6 do título
#
# ## Parágrafos
# ```
# Parágrafo 1
#
# Paragráfo 2
# ```
#
# Parágrafo 1
#
# Paragráfo 2
#
# ## Quebras de Linhas
#
# ```
# Linha 1
# Linha 2
# ```
#
# Linha 1
# Linha 2
#
# ## Enfase no texto
#
# ```
# **Negrito**
# *Itálico*
# ***Negrito e Itálico***
# ```
#
# **Negrito**
# *Itálico*
# ***Negrito e Itálico***
#
# ## Citações
# ```
# > Está é uma citação do Fulano
#
# > Está é a primeira parte da citação do Fulano
# >
# > Está é a segunda parte da citação do Fulano
# ```
#
# > Está é uma citação do Fulano
#
# > Está é a primeira parte da citação do Fulano
# >
# > Está é a segunda parte da citação do Fulano
#
# ## Listas Ordenandas, Não Ordenadas e Aninhadas
# ```
# 1. lista ordenada item
# 1. lista ordenada item
# 1. lista ordenada item
# ```
#
# 1. lista ordenada item  1
# 1. lista ordenada item  2
# 1. lista ordenada item  3
#
# ```
# - lista não ordenada item
# - lista não ordenada item
# - lista não ordenada item
# - lista não ordenada item
# ```
#
# - lista não ordenada item
# - lista não ordenada item
# - lista não ordenada item
# - lista não ordenada item
#
# ```
# + lista não ordenada item
#   + lista não ordenada item
#   + lista não ordenada item
# + lista não ordenada item
#   + lista não ordenada item
#   + lista não ordenada item
# ```
# + lista não ordenada item
#   + lista não ordenada item
#   + lista não ordenada item
# + lista não ordenada item
#   + lista não ordenada item
#   + lista não ordenada item
#
# ## Linhas horizontais
# ```
# ***
# ```
#
# ***
#
# ```
# ---
# ```
#
# ---
#
# ```
# ___
# ```
# ___
#
# ## Links
# ```
# [Tutorial Python](https://docs.python.org/3.6/tutorial/index.html)
# ```
#
# [Tutorial Python](https://docs.python.org/3.6/tutorial/index.html)
#
# ## Imagens
#
# ```
# ![Logo do Python](https://www.python.org/static/img/python-logo.png)
# ```
#
# ![Logo do Python](https://www.python.org/static/img/python-logo.png)
#
#
# ## Tabelas
# ```
#  nome coluna1 | Nome Coluna 2
#  --- | ---
#  valor 1:1 | valor 2:1
#  valor 1:2 | valor 2:2
#  valor 1:3 | valor 2:3
#  valor 1:4 | valor 2:4
# -----------|-----------------
# ```
#
#  nome coluna1 | Nome Coluna 2
#  --- | ---
#  valor 1:1 | valor 2:1
#  valor 1:2 | valor 2:2
#  valor 1:3 | valor 2:3
#  valor 1:4 | valor 2:4
#  --- | ---
#
#
#
#
# ## Tabelas - Alinhamento
# ```
# |  nome coluna1      | Nome Coluna 2 | Nome Coluna 3    |
# | :---        |    :----:   |          ---: |
# | valor      | valor       | valor   |
# | valor   | valor        | valor     |
# ```
#
# |  nome coluna1      | Nome Coluna 2 | Nome Coluna 3    |
# | :---        |    :----:   |          ---: |
# | valor      | valor       | valor   |
# | valor   | valor        | valor     |
#
# ## Lista de tarefas
#
# - [x] item 1
# - [ ] item 2
# - [ ] item 3
#
#
# ## Tachar Texto ~~ ~~
# ~~Este texto foi tachado~~

# %% [markdown]
#  nome coluna1| Nome Coluna 2
#  -|-
#  valor 1:1 | valor 2:1
#  valor 1:2 | valor 2:2
#  valor 1:3 | valor 2:3
#  valor 1:4 | valor 2:4

# %% [markdown]
# # Apresentação do Uso de Fórmula LaTex
# [Referencia LaTeX/Mathematics](https://en.wikibooks.org/wiki/LaTeX/Mathematics#Fractions_and_Binomials)
#
# \begin{equation*}
#  max(X) -min(X)
#  \end{equation*}
#
# ### Média
# \begin{equation*}
#  \frac{\sum_{i=1}^n X_i }{n}
# \end{equation*}
#
# ### Variância Amostral
# \begin{equation*}
#  \frac{\sum_{i=1}^n \left(X_i - \bar{X} \right)^2}{n-1}
# \end{equation*}
#
#
# ### Variância Populacional
# \begin{equation*}
#  \frac{\sum_{i=1}^n \left(X_i - \bar{X} \right)^2}{N}
# \end{equation*}
#
# ### Desvio-padrão Amostral
# \begin{equation*}
#  \sqrt{\frac{\sum_{i=1}^n \left(X_i - \bar{X} \right)^2}{n-1}}
# \end{equation*}
#
# ### Desvio-padrão Populacional
# \begin{equation*}
#  \sqrt{\frac{\sum_{i=1}^n \left(X_i - \bar{X} \right)^2}{N}}
# \end{equation*}

# %% [markdown]
# ## Leituras Adicionais e Referências:
#
# - Python Tutorial at W3Schools: https://www.w3schools.com/python/
# - Python official documentation: https://docs.python.org/3/tutorial/index.html
# - Markdown Guide: https://www.markdownguide.org/basic-syntax/
# - LaTeX/Mathematics: https://en.wikibooks.org/wiki/LaTeX/Mathematics#Fractions_and_Binomials
