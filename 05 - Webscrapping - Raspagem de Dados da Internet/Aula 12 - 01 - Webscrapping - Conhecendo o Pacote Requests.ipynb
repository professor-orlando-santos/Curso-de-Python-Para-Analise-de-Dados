# %% [markdown]
# # 05 - Webscrapping - Raspagem de Dados da Internet
# ## Aula 12 - 01 - Webscrapping - Conhecendo o Pacote Requests

# %% [markdown]
# ## Professor: Orlando Oliveira dos Santos, MsC.
#  - E-mail: professor.orlando.santos@gmail.com
#  - Youtube :https://www.youtube.com/channel/UCPWWbkPWFmOjXH50TQWNAYg
#  - Linkedin: https://linkedin.com/in/orlandoosantos
#  - Facebook: https://www.facebook.com/proforlandosantosmsc/
#  - Twitter: https://twitter.com/ProfOrlandoMsC
#  - Instagram: https://www.instagram.com/proforlandosantosmsc/
#
#
#
# ## Formação Acadêmica
# - Mestrado em Computação Aplicada - UnB (2014 – 2016)
# - MBA, Administração Estratégica de Sistemas de Informação – FGV (2011 – 2013)
# - Tecnólogo em Processamento de Dados, Análise e Desenvolvimento de Sistemas – FAETEC/SP (2000-2002)

# %% [markdown]
# #  Webscrapping - Conhecendo o Pacote Requests

# %% [markdown]
# ## Pacote requests
#
# - Requests é uma biblioteca HTTP para Python simples e elegante, feita para seres humanos.
#
# - https://requests.readthedocs.io/pt_BR/latest/index.html

# %% [markdown]
# ### Instalação

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\python\envs\jupyter\lib\site-packages (2.28.1)
# WARNING: You are using pip version 20.1.1; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\python\envs\jupyter\scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\python\envs\jupyter\lib\site-packages (from requests) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python\envs\jupyter\lib\site-packages (from requests) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python\envs\jupyter\lib\site-packages (from requests) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\python\envs\jupyter\lib\site-packages (from requests) (3.3)

# %% [markdown]
# ## Faça um Requisições Simples

# %%
import requests

# %% [markdown]
# ##Método Get
# get(url, params=None, **kwargs)
#
# O resultado obtido será um objeto response que tem todas as informações sobre o conteúdo requisitado.

# %%
import requests
url = 'https://www.camara.leg.br/deputados/quem-sao/resultado?search=&partido=&uf=&legislatura=56&sexo='
r = requests.get(url)

# %% [markdown]
# ### Checando se a requisição ocorreu com sucesso usando o  atributo "ok"
# - Retorna True se: attr: `status_code` é menor que 400, False se não.
# - Este atributo verifica se o código de status da resposta está entre 400 e 600 para ver se houve um erro do cliente ou do servidor.
# - E se o código de status está entre 200 e 400, isso retornará True

# %%
r.ok
# Out:
# True

# %% [markdown]
# ### Checando o código do status da resposta

# %%
r.status_code
# Out:
# 200

# %% [markdown]
# ### Checando o cabeçalhos da resposta usando um dicionário Python:

# %%
print(r.headers)
# Out:
# {'Date': 'Mon, 26 Sep 2022 23:37:27 GMT', 'Server': 'nginx/1.12.2', 'Content-Type': 'text/html; charset=utf-8', 'Vary': 'Accept-Encoding,User-Agent', 'X-DNS-Prefetch-Control': 'off', 'Expect-CT': 'max-age=0', 'X-Frame-Options': 'SAMEORIGIN', 'Strict-Transport-Security': 'max-age=10', 'X-Download-Options': 'noopen', 'X-Content-Type-Options': 'nosniff', 'X-Permitted-Cross-Domain-Policies': 'none', 'Referrer-Policy': 'origin-when-cross-origin', 'X-XSS-Protection': '1; mode=block', 'Cache-control': 'private', 'X-Cache-Status': 'MISS', 'Set-Cookie': 'KUB=kub07|YzI3u|YzI3u; path=/', 'Content-Encoding': 'gzip', 'Content-Length': '9152', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive'}

# %% [markdown]
# ### Verificando o enconding inferido do texto
# - Será usando par decodificar o texto ao chamar o método r.text
# - Se não estiver correto, pode ser alterado. Por Exemplo: ```r.encoding = utf-8```

# %%
r.encoding
# Out:
# 'utf-8'

# %% [markdown]
# ### Obtendo o conteúdo do Response em texto Unicode.
#  - Se Response.encoding for None, a codificação será adivinhada ```r.encoding```.  Lembre que você pode alterar se necesário.

# %%
r.text
# Out:
# '<!doctype html>\n<!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="pt-br"> <![endif]-->\n<!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8" lang="pt-br"> <![endif]-->\n<!--[if IE 8]>         <html class="no-js lt-ie9" lang="pt-br"> <![endif]-->\n<!--[if gt IE 8]><!-->\n<html class="no-js" lang="pt-br">\n<!--<![endif]-->\n\n<head>\n\n  <meta charset="utf-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n  <meta http-equiv="x-ua-compatible" content="ie=edge">\n  \n  <title>\n      Busca de Deputados na Câmara dos Deputados - Portal da Câmara dos Deputados\n  </title>\n  <meta name="description" content="Busque um deputado, conheça e acompanhe seu trabalho">\n  \n  <meta name="msapplication-TileColor" content="#00a300">\n  <meta name="msapplication-TileImage" content="https://www.camara.leg.br/tema/mstile-144x144.png">\n  <meta name="theme-color" content="#009e49">\n  \n  \n  <meta itemprop="name" content="Busca de Deputados na Câmara dos Deputados" />\n  \n  <meta itemprop="description" content="Busque um deputado, conheça e acompanhe seu trabalho" />\n  \n  <meta itemprop="image" content="https://www.camara.leg.br/tema/assets/images/imagens-compartilhamento/deputados.jpg" />\n  \n  <meta property="og:site_name" content="Portal da Câmara dos Deputados" />\n  <meta property="fb:app_id" content="305358806340223" />\n  \n  <meta property="og:title" content="Busca de Deputados na Câmara dos Deputados" />\n  \n  <meta property="og:description" content="Busque um deputado, conheça e acompanhe seu trabalho">\n  \n  \n  <meta property="og:type" content="website" />\n  \n  <meta property="og:image:secure_url" content="https://www.camara.leg.br/tema/assets/images/imagens-compartilhamento/deputados.jpg" />\n  \n      <meta property="og:image" content="https://www.camara.leg.br/tema/assets/images/imagens-compartilhamento/deputados.jpg" />\n  <meta name="twitter:card" content="summary" />\n  \n  <meta name="twitter:title" content="Busca de Deputados na Câmara dos Deputados" />\n  \n  <meta name="twitter:description" content="Busque um deputado, conheça e acompanhe seu trabalho" />\n  \n  <meta name="twitter:image" content="https://www.camara.leg.br/tema/assets/images/imagens-compartilhamento/deputados.jpg" />\n  \n  \n  \n  \n\n  <link rel="apple-touch-icon" href="https://www.camara.leg.br/tema/apple-touch-icon.png">\n  <link rel="apple-touch-icon" sizes="152x152" href="https://www.camara.leg.br/tema/apple-touch-icon-152x152.png">\n  <link rel="apple-touch-icon" sizes="180x180" href="https://www.camara.leg.br/tema/apple-touch-icon-180x180.png">\n  <link rel="apple-touch-icon-precomposed" href="https://www.camara.leg.br/tema/apple-touch-icon-precomposed.png">\n  <link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://www.camara.leg.br/tema/apple-touch-icon-152x152-precomposed.png">\n  <link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://www.camara.leg.br/tema/apple-touch-icon-180x180-precomposed.png">\n  <link rel="icon" type="image/png" sizes="32x32" href="https://www.camara.leg.br/tema/favicon-32x32.png">\n  <link rel="icon" type="image/png" sizes="16x16" href="https://www.camara.leg.br/tema/favicon-16x16.png">\n  <link rel="manifest" href="https://www.camara.leg.br/tema/site.webmanifest">\n  <link rel="mask-icon" href="https://www.camara.leg.br/tema/safari-pinned-tab.svg" color="#009e49">\n  <link rel="stylesheet" rel="preload" as="style" href="https://www.camara.leg.br/tema/global/vendor-bundle.css">\n  <link rel="stylesheet" rel="preload" as="style" href="https://www.camara.leg.br/tema/global/camara-custom.css">\n\n        <link rel="stylesheet" href="https://www.camara.leg.br/tema/deputados/busca-deputados-resultados.css">\n\n  <style type="text/css">\n    /* Regra geral para no-fouc */\n    .js .u-no-fouc {\n      visibility: hidden;\n      opacity: 0\n    }\n\n    /* Elementos no-fouc que não podem ocupar espaço durante a carga da  ...

# %% [markdown]
# ### Obtendo o conteúdo do Response em bytes

# %%
r.content
# Out:
# b'<!doctype html>\n<!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="pt-br"> <![endif]-->\n<!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8" lang="pt-br"> <![endif]-->\n<!--[if IE 8]>         <html class="no-js lt-ie9" lang="pt-br"> <![endif]-->\n<!--[if gt IE 8]><!-->\n<html class="no-js" lang="pt-br">\n<!--<![endif]-->\n\n<head>\n\n  <meta charset="utf-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n  <meta http-equiv="x-ua-compatible" content="ie=edge">\n  \n  <title>\n      Busca de Deputados na C\xc3\xa2mara dos Deputados - Portal da C\xc3\xa2mara dos Deputados\n  </title>\n  <meta name="description" content="Busque um deputado, conhe\xc3\xa7a e acompanhe seu trabalho">\n  \n  <meta name="msapplication-TileColor" content="#00a300">\n  <meta name="msapplication-TileImage" content="https://www.camara.leg.br/tema/mstile-144x144.png">\n  <meta name="theme-color" content="#009e49">\n  \n  \n  <meta itemprop="name" content="Busca de Deputados na C\xc3\xa2mara dos Deputados" />\n  \n  <meta itemprop="description" content="Busque um deputado, conhe\xc3\xa7a e acompanhe seu trabalho" />\n  \n  <meta itemprop="image" content="https://www.camara.leg.br/tema/assets/images/imagens-compartilhamento/deputados.jpg" />\n  \n  <meta property="og:site_name" content="Portal da C\xc3\xa2mara dos Deputados" />\n  <meta property="fb:app_id" content="305358806340223" />\n  \n  <meta property="og:title" content="Busca de Deputados na C\xc3\xa2mara dos Deputados" />\n  \n  <meta property="og:description" content="Busque um deputado, conhe\xc3\xa7a e acompanhe seu trabalho">\n  \n  \n  <meta property="og:type" content="website" />\n  \n  <meta property="og:image:secure_url" content="https://www.camara.leg.br/tema/assets/images/imagens-compartilhamento/deputados.jpg" />\n  \n      <meta property="og:image" content="https://www.camara.leg.br/tema/assets/images/imagens-compartilhamento/deputados.jpg" />\n  <meta name="twitter:card" content="summary" />\n  \n  <meta name="twitter:title" content="Busca de Deputados na C\xc3\xa2mara dos Deputados" />\n  \n  <meta name="twitter:description" content="Busque um deputado, conhe\xc3\xa7a e acompanhe seu trabalho" />\n  \n  <meta name="twitter:image" content="https://www.camara.leg.br/tema/assets/images/imagens-compartilhamento/deputados.jpg" />\n  \n  \n  \n  \n\n  <link rel="apple-touch-icon" href="https://www.camara.leg.br/tema/apple-touch-icon.png">\n  <link rel="apple-touch-icon" sizes="152x152" href="https://www.camara.leg.br/tema/apple-touch-icon-152x152.png">\n  <link rel="apple-touch-icon" sizes="180x180" href="https://www.camara.leg.br/tema/apple-touch-icon-180x180.png">\n  <link rel="apple-touch-icon-precomposed" href="https://www.camara.leg.br/tema/apple-touch-icon-precomposed.png">\n  <link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://www.camara.leg.br/tema/apple-touch-icon-152x152-precomposed.png">\n  <link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://www.camara.leg.br/tema/apple-touch-icon-180x180-precomposed.png">\n  <link rel="icon" type="image/png" sizes="32x32" href="https://www.camara.leg.br/tema/favicon-32x32.png">\n  <link rel="icon" type="image/png" sizes="16x16" href="https://www.camara.leg.br/tema/favicon-16x16.png">\n  <link rel="manifest" href="https://www.camara.leg.br/tema/site.webmanifest">\n  <link rel="mask-icon" href="https://www.camara.leg.br/tema/safari-pinned-tab.svg" color="#009e49">\n  <link rel="stylesheet" rel="preload" as="style" href="https://www.camara.leg.br/tema/global/vendor-bundle.css">\n  <link rel="stylesheet" rel="preload" as="style" href="https://www.camara.leg.br/tema/global/camara-custom.css">\n\n        <link rel="stylesheet" href="https://www.camara.leg.br/tema/deputados/busca-deputados-resultados.css">\n\n  <style type="text/css">\n    /* Regra geral para no-fouc */\n    .js .u-no-fouc {\n      visibility: hidden;\n      opacity: 0\n    }\n\n  ...

# %% [markdown]
# ## Acessar o conteúdo por chunks de forma iterativa

# %%
for data in list(r.iter_content(chunk_size=100))[:10]:
    print(data)
# Out:
# b'<!doctype html>\n<!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="pt-br"> <![end'
# b'if]-->\n<!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8" lang="pt-br"> <![endif]-->\n<!--[if I'
# b'E 8]>         <html class="no-js lt-ie9" lang="pt-br"> <![endif]-->\n<!--[if gt IE 8]><!-->\n<html cla'
# b'ss="no-js" lang="pt-br">\n<!--<![endif]-->\n\n<head>\n\n  <meta charset="utf-8">\n  <meta name="viewport" '
# b'content="width=device-width, initial-scale=1, shrink-to-fit=no">\n  <meta http-equiv="x-ua-compatible'
# b'" content="ie=edge">\n  \n  <title>\n      Busca de Deputados na C\xc3\xa2mara dos Deputados - Portal da C\xc3\xa2m'
# b'ara dos Deputados\n  </title>\n  <meta name="description" content="Busque um deputado, conhe\xc3\xa7a e acom'
# b'panhe seu trabalho">\n  \n  <meta name="msapplication-TileColor" content="#00a300">\n  <meta name="msap'
# b'plication-TileImage" content="https://www.camara.leg.br/tema/mstile-144x144.png">\n  <meta name="them'
# b'e-color" content="#009e49">\n  \n  \n  <meta itemprop="name" content="Busca de Deputados na C\xc3\xa2mara dos'

# %% [markdown]
# ## Acessar o conteúdo por linhas de forma iterativa

# %%
for data in list(r.iter_lines())[:10]:
    print(data)
# Out:
# b'[{"id":"CL","nome":"Cadastro Central de Empresas","agregados":[{"id":"1732","nome":"Dados gerais das empresas por faixas de pessoal ocupado total, segundo se\xc3\xa7\xc3\xa3o, divis\xc3\xa3o e grupo da classifica\xc3\xa7\xc3\xa3o de atividades, em n\xc3\xadvel Brasil, Grandes Regi\xc3\xb5es e Unidades da Federa\xc3\xa7\xc3\xa3o da sede da empresa"},{"id":"1735","nome":"Dados gerais das unidades locais por faixas de pessoal ocupado total, segundo se\xc3\xa7\xc3\xa3o da classifica\xc3\xa7\xc3\xa3o de atividades, em n\xc3\xadvel Brasil, Grandes Regi\xc3\xb5es, Unidades da Federa\xc3\xa7\xc3\xa3o e Municip\xc3\xados"},{"id":"1734","nome":"Dados gerais das unidades locais por faixas de pessoal ocupado total, segundo se\xc3\xa7\xc3\xa3o e divis\xc3\xa3o da classifica\xc3\xa7\xc3\xa3o de atividades, em n\xc3\xadvel Brasil, Grandes Regi\xc3\xb5es, Unidades da Federa\xc3\xa7\xc3\xa3o e Municip\xc3\xados das Capitais"},{"id":"1733","nome":"Dados gerais das unidades locais por faixas de pessoal ocupado total, segundo se\xc3\xa7\xc3\xa3o, divis\xc3\xa3o e grupo da classifica\xc3\xa7\xc3\xa3o de atividades, em n\xc3\xadvel Brasil, Grandes Regi\xc3\xb5es e Unidades da Federa\xc3\xa7\xc3\xa3o"},{"id":"2869","nome":"Empresas e outras organiza\xc3\xa7\xc3\xb5es e suas unidades locais, pessoal ocupado total e assalariado, sal\xc3\xa1rios e outras remunera\xc3\xa7\xc3\xb5es e sal\xc3\xa1rio m\xc3\xa9dio mensal, por se\xc3\xa7\xc3\xa3o, divis\xc3\xa3o e grupo da classifica\xc3\xa7\xc3\xa3o de atividades, faixas de pessoal ocupado total e natureza jur\xc3\xaddica, em n\xc3\xadvel Brasil, Grandes Regi\xc3\xb5es e Unidades da Federa\xc3\xa7\xc3\xa3o da sede da empresa"},{"id":"992","nome":"Empresas e outras organiza\xc3\xa7\xc3\xb5es, pessoal ocupado total, pessoal ocupado assalariado, pessoal assalariado m\xc3\xa9dio, sal\xc3\xa1rios e outras remunera\xc3\xa7\xc3\xb5es e sal\xc3\xa1rio m\xc3\xa9dio mensal, por se\xc3\xa7\xc3\xa3o, divis\xc3\xa3o e grupo da classifica\xc3\xa7\xc3\xa3o de atividades (CNAE 2.0), faixas de pessoal ocupado total e natureza jur\xc3\xaddica"},{"id":"6449","nome":"Empresas e outras organiza\xc3\xa7\xc3\xb5es, pessoal ocupado total, pessoal ocupado assalariado, sal\xc3\xa1rios e outras remunera\xc3\xa7\xc3\xb5es, por se\xc3\xa7\xc3\xa3o, divis\xc3\xa3o, grupo e classe da classifica\xc3\xa7\xc3\xa3o de atividades (CNAE 2.0)"},{"id":"2933","nome":"Empresas e outras organiza\xc3\xa7\xc3\xb5es, por ano de funda\xc3\xa7\xc3\xa3o, se\xc3\xa7\xc3\xa3o da classifica\xc3\xa7\xc3\xa3o de atividades e faixas de pessoal ocupado total"},{"id":"993","nome":"Empresas e outras organiza\xc3\xa7\xc3\xb5es, por se\xc3\xa7\xc3\xa3o da classifica\xc3\xa7\xc3\xa3o de atividades (CNAE 2.0), faixas de pessoal ocupado total e ano de funda\xc3\xa7\xc3\xa3o"},{"id":"2934","nome":"Empresas, pessoal ocupado total e indicadores de concentra\xc3\xa7\xc3\xa3o econ\xc3\xb4mica em rela\xc3\xa7\xc3\xa3o \xc3\xa0 vari\xc3\xa1vel pessoal ocupado total das maiores empresas, por se\xc3\xa7\xc3\xa3o, divis\xc3\xa3o e grupo da classifica\xc3\xa7\xc3\xa3o de atividades"},{"id":"994","nome":"Empresas, pessoal ocupado total e indicadores de concentra\xc3\xa7\xc3\xa3o econ\xc3\xb4mica em rela\xc3\xa7\xc3\xa3o \xc3\xa0 vari\xc3\xa1vel pessoal ocupado total das maiores empresas, por se\xc3\xa7\xc3\xa3o, divis\xc3\xa3o e grupo da classifica\xc3\xa7\xc3\xa3o de atividades (CNAE 2.0)"},{"id":"995","nome":"Empresas, pessoal ocupado total e indicadores de diversifica\xc3\xa7\xc3\xa3o espacial e de atividades no total de empresas e nas empresas com mais de uma unidade local, por se\xc3\xa7\xc3\xa3o, divis\xc3\xa3o e grupo da classifica\xc3\xa7\xc3\xa3o de atividades (CNAE 2.0) e tipo de empresa"},{"id":"2937","nome":"Empresas, pessoal ocupado total e indicadores de diversifica\xc3\xa7\xc3\xa3o espacial e de atividades no total de empresas e nas empresas com mais de uma unidade local, por se\xc3\xa7\xc3\xa3o, divis\xc3\xa3o e grupo da classifica\xc3\xa7\xc3\xa3o de atividade ...

# %% [markdown]
# ## Decodificando o conteúdo no formato Json com método response.json()
#
# ### Exemplo de Acesso a API de localidades do IBGE

# %%
import requests
url = 'https://servicodados.ibge.gov.br/api/v1/localidades/estados'
r = requests.get(url)
json_pesquisas = r.json()

for estado in json_pesquisas:
  print(estado)
# Out:
# {'id': 11, 'sigla': 'RO', 'nome': 'Rondônia', 'regiao': {'id': 1, 'sigla': 'N', 'nome': 'Norte'}}
# {'id': 12, 'sigla': 'AC', 'nome': 'Acre', 'regiao': {'id': 1, 'sigla': 'N', 'nome': 'Norte'}}
# {'id': 13, 'sigla': 'AM', 'nome': 'Amazonas', 'regiao': {'id': 1, 'sigla': 'N', 'nome': 'Norte'}}
# {'id': 14, 'sigla': 'RR', 'nome': 'Roraima', 'regiao': {'id': 1, 'sigla': 'N', 'nome': 'Norte'}}
# {'id': 15, 'sigla': 'PA', 'nome': 'Pará', 'regiao': {'id': 1, 'sigla': 'N', 'nome': 'Norte'}}
# {'id': 16, 'sigla': 'AP', 'nome': 'Amapá', 'regiao': {'id': 1, 'sigla': 'N', 'nome': 'Norte'}}
# {'id': 17, 'sigla': 'TO', 'nome': 'Tocantins', 'regiao': {'id': 1, 'sigla': 'N', 'nome': 'Norte'}}
# {'id': 21, 'sigla': 'MA', 'nome': 'Maranhão', 'regiao': {'id': 2, 'sigla': 'NE', 'nome': 'Nordeste'}}
# {'id': 22, 'sigla': 'PI', 'nome': 'Piauí', 'regiao': {'id': 2, 'sigla': 'NE', 'nome': 'Nordeste'}}
# {'id': 23, 'sigla': 'CE', 'nome': 'Ceará', 'regiao': {'id': 2, 'sigla': 'NE', 'nome': 'Nordeste'}}
# {'id': 24, 'sigla': 'RN', 'nome': 'Rio Grande do Norte', 'regiao': {'id': 2, 'sigla': 'NE', 'nome': 'Nordeste'}}
# {'id': 25, 'sigla': 'PB', 'nome': 'Paraíba', 'regiao': {'id': 2, 'sigla': 'NE', 'nome': 'Nordeste'}}
# {'id': 26, 'sigla': 'PE', 'nome': 'Pernambuco', 'regiao': {'id': 2, 'sigla': 'NE', 'nome': 'Nordeste'}}
# {'id': 27, 'sigla': 'AL', 'nome': 'Alagoas', 'regiao': {'id': 2, 'sigla': 'NE', 'nome': 'Nordeste'}}
# {'id': 28, 'sigla': 'SE', 'nome': 'Sergipe', 'regiao': {'id': 2, 'sigla': 'NE', 'nome': 'Nordeste'}}
# {'id': 29, 'sigla': 'BA', 'nome': 'Bahia', 'regiao': {'id': 2, 'sigla': 'NE', 'nome': 'Nordeste'}}
# {'id': 31, 'sigla': 'MG', 'nome': 'Minas Gerais', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}
# {'id': 32, 'sigla': 'ES', 'nome': 'Espírito Santo', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}
# {'id': 33, 'sigla': 'RJ', 'nome': 'Rio de Janeiro', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}
# {'id': 35, 'sigla': 'SP', 'nome': 'São Paulo', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}
# {'id': 41, 'sigla': 'PR', 'nome': 'Paraná', 'regiao': {'id': 4, 'sigla': 'S', 'nome': 'Sul'}}
# {'id': 42, 'sigla': 'SC', 'nome': 'Santa Catarina', 'regiao': {'id': 4, 'sigla': 'S', 'nome': 'Sul'}}
# {'id': 43, 'sigla': 'RS', 'nome': 'Rio Grande do Sul', 'regiao': {'id': 4, 'sigla': 'S', 'nome': 'Sul'}}
# {'id': 50, 'sigla': 'MS', 'nome': 'Mato Grosso do Sul', 'regiao': {'id': 5, 'sigla': 'CO', 'nome': 'Centro-Oeste'}}
# {'id': 51, 'sigla': 'MT', 'nome': 'Mato Grosso', 'regiao': {'id': 5, 'sigla': 'CO', 'nome': 'Centro-Oeste'}}
# {'id': 52, 'sigla': 'GO', 'nome': 'Goiás', 'regiao': {'id': 5, 'sigla': 'CO', 'nome': 'Centro-Oeste'}}
# {'id': 53, 'sigla': 'DF', 'nome': 'Distrito Federal', 'regiao': {'id': 5, 'sigla': 'CO', 'nome': 'Centro-Oeste'}}

# %% [markdown]
# ### Exemplo de Acesso a API de agregados do IBGE
#
# ### Obtendo a lista de agregados

# %%
import requests
url = 'https://servicodados.ibge.gov.br/api/v3/agregados'
r = requests.get(url)
json_agregados = r.json()
sorted([(i, pesq['nome'], pesq['id']) for i, pesq in enumerate(json_agregados)], key = lambda x : x[1])
# Out:
# [(0, 'Cadastro Central de Empresas', 'CL'),
#  (1, 'Censo Agropecuário', 'CA'),
#  (2, 'Censo Comum do Mercosul, Bolívia e Chile', 'ME'),
#  (3, 'Censo Demográfico', 'CD'),
#  (4, 'Contagem da População ', 'CM'),
#  (7, 'Contas Econômicas Ambientais da Água', 'C4'),
#  (8, 'Contas Econômicas Ambientais de Energia: produtos da biomassa', 'DZ'),
#  (9, 'Contas Nacionais Anuais', 'SU'),
#  (10, 'Contas Nacionais Trimestrais', 'ST'),
#  (6, 'Contas de Espécies Ameaçadas ', 'DT'),
#  (5, 'Contas de ecossistemas: o uso da terra nos biomas brasileiros', 'DU'),
#  (11, 'Demografia das Empresas e Estatísticas de Empreendedorismo', 'DE'),
#  (12, 'Estimativas de População', 'XF'),
#  (13, 'Fundações Privadas e Associações Sem Fins Lucrativos', 'FP'),
#  (14, 'Indicadores de Desenvolvimento Sustentável', 'IU'),
#  (23, 'Levantamento Sistemático da Produção Agrícola', 'LA'),
#  (24, 'Objetivos de Desenvolvimento Sustentável', 'C2'),
#  (25, 'Pesquisa Anual da Indústria da Construção', 'AC'),
#  (26, 'Pesquisa Anual de Comércio', 'PB'),
#  (27, 'Pesquisa Anual de Serviços', 'PY'),
#  (37, 'Pesquisa Estatísticas do Registro Civil', 'RC'),
#  (38, 'Pesquisa Industrial Anual', 'PI'),
#  (39, 'Pesquisa Industrial Anual - Empresa', 'PK'),
#  (40, 'Pesquisa Industrial Anual - Produto', 'PJ'),
#  (41, 'Pesquisa Industrial Mensal - Dados Gerais', 'DG'),
#  (42, 'Pesquisa Industrial Mensal - Produção Física', 'PZ'),
#  (43, 'Pesquisa Industrial Mensal de Emprego e Salário', 'XY'),
#  (44, 'Pesquisa Mensal de Abate de Animais', 'AB'),
#  (45, 'Pesquisa Mensal de Comércio', 'MC'),
#  (46, 'Pesquisa Mensal de Emprego', 'PE'),
#  (47, 'Pesquisa Mensal de Serviços', 'SC'),
#  (48, 'Pesquisa Mensal do Leite', 'PL'),
#  (49, 'Pesquisa Nacional de Saneamento Básico', 'SB'),
#  (50, 'Pesquisa Nacional de Saúde', 'XN'),
#  (51, 'Pesquisa Nacional de Saúde do Escolar', 'AA'),
#  (52, 'Pesquisa Nacional por Amostra de Domicílios', 'PD'),
#  (53, 'Pesquisa Nacional por Amostra de Domicílios Contínua anual', 'B5'),
#  (54, 'Pesquisa Nacional por Amostra de Domicílios Contínua mensal', 'BB'),
#  (55, 'Pesquisa Nacional por Amostra de Domicílios Contínua trimestral', 'DD'),
#  (56, 'Pesquisa Trimestral do Abate de Animais', 'AX'),
#  (57, 'Pesquisa Trimestral do Couro', 'CQ'),
#  (58, 'Pesquisa Trimestral do Leite', 'LT'),
#  (28, 'Pesquisa da Pecuária Municipal', 'PP'),
#  (29, 'Pesquisa de Assistência Médico-Sanitária', 'AM'),
#  (30, 'Pesquisa de Estoques', 'ES'),
#  (31, 'Pesquisa de Informações Básicas Municipais', 'PM'),
#  (32, 'Pesquisa de Inovação', 'IT'),
#  (33, 'Pesquisa de Orçamentos Familiares', 'OF'),
#  (34, 'Pesquisa de Serviços de Hospedagem', 'SH'),
#  (35, 'Pesquisa de Serviços de Publicidade e Promoção', 'SE'),
#  (36, 'Pesquisa de Serviços de Tecnologia da Informação', 'PT'),
#  (62, 'Produto Interno Bruto dos Municípios', 'IO'),
#  (59, 'Produção Agrícola Municipal', 'PA'),
#  (60, 'Produção da Extração Vegetal e da Silvicultura', 'VS'),
#  (61, 'Produção de Ovos de Galinha', 'PO'),
#  (63, 'Projeção da População', 'XE'),
#  (64,
#   'Sistema Nacional de Pesquisa de Custos e Índices da Construção Civil',
#   'SI'),
#  (18, 'Índice Nacional de Preços ao Consumidor', 'PC'),
#  (19, 'Índice Nacional de Preços ao Consumidor Amplo', 'IA'),
#  (20, 'Índice Nacional de Preços ao Consumidor Amplo 15', 'IQ'),
#  (21, 'Índice Nacional de Preços ao Consumidor Amplo Especial', 'IG'),
#  (22, 'Índice Nacional de Preços ao Consumidor Especial', 'PG'),
#  (15, 'Índice de Preços ao Consumidor em Real', 'IL'),
#  (16, 'Índice de Preços ao Produtor', 'IR'),
#  (17, 'Índice de Reajuste do Salário Mínimo', 'IJ')]

# %% [markdown]
# #### Verificando as series históricas de PIB

# %%
json_agregados[60]
# Out:
# {'id': 'VS',
#  'nome': 'Produção da Extração Vegetal e da Silvicultura',
#  'agregados': [{'id': '5930',
#    'nome': 'Área total existente em 31/12 dos efetivos da silvicultura, por espécie florestal'},
#   {'id': '289',
#    'nome': 'Quantidade produzida e valor da produção na extração vegetal, por tipo de produto extrativo'},
#   {'id': '291',
#    'nome': 'Quantidade produzida e valor da produção na silvicultura, por tipo de produto da silvicultura'},
#   {'id': '290',
#    'nome': 'Valor da produção na extração vegetal, por tipo de produto extrativo (série encerrada)'},
#   {'id': '292',
#    'nome': 'Valor da produção na silvicultura, por tipo de produto da silvicultura (série encerrada)'}]}

# %% [markdown]
# ### Exemplo de Acesso ao Dados de PIB a preços correntes dos estados
#
# #### Usar o construtor de consultas da API de agregados do IBGE para criar a url desejada
# - endereço de construtor de consultas da API: https://servicodados.ibge.gov.br/api/docs/agregados?versao=3#api-bq
#
#
# #### Acessar o conteúdo usando o requests

# %%
import requests
url = 'https://servicodados.ibge.gov.br/api/v3/agregados/5938/periodos/2002|2003|2004|2005|2006|2007|2008|2009|2010|2011|2012|2013|2014|2015|2016|2017/variaveis/37?localidades=N3[all]'
r = requests.get(url)
json_agregado_pib_estadual = r.json()

# %%
json_agregado_pib_estadual[0]['resultados'][0]['series'][0]
# Out:
# {'localidade': {'id': '11',
#   'nivel': {'id': 'N3', 'nome': 'Unidade da Federação'},
#   'nome': 'Rondônia'},
#  'serie': {'2002': '7467630',
#   '2003': '9425010',
#   '2004': '11004641',
#   '2005': '12511821',
#   '2006': '13054713',
#   '2007': '14438376',
#   '2008': '17285542',
#   '2009': '19725010',
#   '2010': '23907887',
#   '2011': '27574714',
#   '2012': '30112720',
#   '2013': '31121413',
#   '2014': '34030982',
#   '2015': '36563333',
#   '2016': '39460359',
#   '2017': '43516147'}}

# %% [markdown]
# ### Exemplo de Acesso ao Dados de população estimada dos estados

# %%
import requests
url = 'https://servicodados.ibge.gov.br/api/v3/agregados/6579/periodos/2001|2002|2003|2004|2005|2006|2008|2009|2011|2012|2013|2014|2015|2016|2017|2018|2019|2020/variaveis/9324?localidades=N3[all]'
r = requests.get(url)
json_agregado_pop_estadual = r.json()

# %%
json_agregado_pop_estadual[0]['resultados'][0]['series'][0]
# Out:
# {'localidade': {'id': '11',
#   'nivel': {'id': 'N3', 'nome': 'Unidade da Federação'},
#   'nome': 'Rondônia'},
#  'serie': {'2001': '1407886',
#   '2002': '1431777',
#   '2003': '1455907',
#   '2004': '1562085',
#   '2005': '1534594',
#   '2006': '1562417',
#   '2008': '1493565',
#   '2009': '1503928',
#   '2011': '1576455',
#   '2012': '1590011',
#   '2013': '1728214',
#   '2014': '1748531',
#   '2015': '1768204',
#   '2016': '1787279',
#   '2017': '1805788',
#   '2018': '1757589',
#   '2019': '1777225',
#   '2020': '1796460'}}

# %% [markdown]
# ## configurando  Cabeçalhos personalizados
# Para adicionar cabeçalhos HTTP para uma requisição, simplesmente passe-os em um dict para o parâmetro headers.
#
# ### Escolhendo o formato do arquivo desejando na API da Câmara dos Deputados
# - Escolhendo o formado xml

# %%
import requests
url = 'https://dadosabertos.camara.leg.br/api/v2/deputados' 
headers = {'accept': 'text/xml'}
r = requests.get(url, headers=headers)
r.text
# Out:
# "<xml><dados><deputado_><id>204521</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/204521</uri><nome>Abou Anni</nome><siglaPartido>UNIÃO</siglaPartido><uriPartido>https://dadosabertos.camara.leg.br/api/v2/partidos/38009</uriPartido><siglaUf>SP</siglaUf><idLegislatura>56</idLegislatura><urlFoto>https://www.camara.leg.br/internet/deputado/bandep/204521.jpg</urlFoto><email/></deputado_><deputado_><id>204379</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/204379</uri><nome>Acácio Favacho</nome><siglaPartido>MDB</siglaPartido><uriPartido>https://dadosabertos.camara.leg.br/api/v2/partidos/36899</uriPartido><siglaUf>AP</siglaUf><idLegislatura>56</idLegislatura><urlFoto>https://www.camara.leg.br/internet/deputado/bandep/204379.jpg</urlFoto><email/></deputado_><deputado_><id>204560</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/204560</uri><nome>Adolfo Viana</nome><siglaPartido>PSDB</siglaPartido><uriPartido>https://dadosabertos.camara.leg.br/api/v2/partidos/36835</uriPartido><siglaUf>BA</siglaUf><idLegislatura>56</idLegislatura><urlFoto>https://www.camara.leg.br/internet/deputado/bandep/204560.jpg</urlFoto><email/></deputado_><deputado_><id>204528</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/204528</uri><nome>Adriana Ventura</nome><siglaPartido>NOVO</siglaPartido><uriPartido>https://dadosabertos.camara.leg.br/api/v2/partidos/37901</uriPartido><siglaUf>SP</siglaUf><idLegislatura>56</idLegislatura><urlFoto>https://www.camara.leg.br/internet/deputado/bandep/204528.jpg</urlFoto><email/></deputado_><deputado_><id>121948</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/121948</uri><nome>Adriano do Baldy</nome><siglaPartido>PP</siglaPartido><uriPartido>https://dadosabertos.camara.leg.br/api/v2/partidos/37903</uriPartido><siglaUf>GO</siglaUf><idLegislatura>56</idLegislatura><urlFoto>https://www.camara.leg.br/internet/deputado/bandep/121948.jpg</urlFoto><email/></deputado_><deputado_><id>74646</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/74646</uri><nome>Aécio Neves</nome><siglaPartido>PSDB</siglaPartido><uriPartido>https://dadosabertos.camara.leg.br/api/v2/partidos/36835</uriPartido><siglaUf>MG</siglaUf><idLegislatura>56</idLegislatura><urlFoto>https://www.camara.leg.br/internet/deputado/bandep/74646.jpg</urlFoto><email/></deputado_><deputado_><id>141372</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/141372</uri><nome>Aelton Freitas</nome><siglaPartido>PP</siglaPartido><uriPartido>https://dadosabertos.camara.leg.br/api/v2/partidos/37903</uriPartido><siglaUf>MG</siglaUf><idLegislatura>56</idLegislatura><urlFoto>https://www.camara.leg.br/internet/deputado/bandep/141372.jpg</urlFoto><email/></deputado_><deputado_><id>160508</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/160508</uri><nome>Afonso Florence</nome><siglaPartido>PT</siglaPartido><uriPartido>https://dadosabertos.camara.leg.br/api/v2/partidos/36844</uriPartido><siglaUf>BA</siglaUf><idLegislatura>56</idLegislatura><urlFoto>https://www.camara.leg.br/internet/deputado/bandep/160508.jpg</urlFoto><email/></deputado_><deputado_><id>136811</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/136811</uri><nome>Afonso Hamm</nome><siglaPartido>PP</siglaPartido><uriPartido>https://dadosabertos.camara.leg.br/api/v2/partidos/37903</uriPartido><siglaUf>RS</siglaUf><idLegislatura>56</idLegislatura><urlFoto>https://www.camara.leg.br/internet/deputado/bandep/136811.jpg</urlFoto><email/></deputado_><deputado_><id>178835</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/178835</uri><nome>Afonso Motta</nome><siglaPartido>PDT</siglaPartido><uriPartido>https://dadosabertos.camara.leg.br/api/v2/partidos/36786</uriPartido><siglaUf>RS</siglaUf><idLegislatura>56</idLegislatura><urlFoto>https://www.camara.leg.br/internet/deputado/bandep/178835.jpg</urlFoto><email/></deputado_><deputado_><id>204495</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/204495</uri><nome>Airton Fa ...

# %%
import requests
url = 'https://dadosabertos.camara.leg.br/api/v2/deputados' 
headers = {'accept': 'application/xml'}
r = requests.get(url, headers=headers)
r.text
# Out:
# "<xml><dados><deputado_><id>204521</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/204521</uri><nome>Abou Anni</nome><siglaPartido>UNIÃO</siglaPartido><uriPartido>https://dadosabertos.camara.leg.br/api/v2/partidos/38009</uriPartido><siglaUf>SP</siglaUf><idLegislatura>56</idLegislatura><urlFoto>https://www.camara.leg.br/internet/deputado/bandep/204521.jpg</urlFoto><email/></deputado_><deputado_><id>204379</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/204379</uri><nome>Acácio Favacho</nome><siglaPartido>MDB</siglaPartido><uriPartido>https://dadosabertos.camara.leg.br/api/v2/partidos/36899</uriPartido><siglaUf>AP</siglaUf><idLegislatura>56</idLegislatura><urlFoto>https://www.camara.leg.br/internet/deputado/bandep/204379.jpg</urlFoto><email/></deputado_><deputado_><id>204560</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/204560</uri><nome>Adolfo Viana</nome><siglaPartido>PSDB</siglaPartido><uriPartido>https://dadosabertos.camara.leg.br/api/v2/partidos/36835</uriPartido><siglaUf>BA</siglaUf><idLegislatura>56</idLegislatura><urlFoto>https://www.camara.leg.br/internet/deputado/bandep/204560.jpg</urlFoto><email/></deputado_><deputado_><id>204528</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/204528</uri><nome>Adriana Ventura</nome><siglaPartido>NOVO</siglaPartido><uriPartido>https://dadosabertos.camara.leg.br/api/v2/partidos/37901</uriPartido><siglaUf>SP</siglaUf><idLegislatura>56</idLegislatura><urlFoto>https://www.camara.leg.br/internet/deputado/bandep/204528.jpg</urlFoto><email/></deputado_><deputado_><id>121948</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/121948</uri><nome>Adriano do Baldy</nome><siglaPartido>PP</siglaPartido><uriPartido>https://dadosabertos.camara.leg.br/api/v2/partidos/37903</uriPartido><siglaUf>GO</siglaUf><idLegislatura>56</idLegislatura><urlFoto>https://www.camara.leg.br/internet/deputado/bandep/121948.jpg</urlFoto><email/></deputado_><deputado_><id>74646</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/74646</uri><nome>Aécio Neves</nome><siglaPartido>PSDB</siglaPartido><uriPartido>https://dadosabertos.camara.leg.br/api/v2/partidos/36835</uriPartido><siglaUf>MG</siglaUf><idLegislatura>56</idLegislatura><urlFoto>https://www.camara.leg.br/internet/deputado/bandep/74646.jpg</urlFoto><email/></deputado_><deputado_><id>141372</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/141372</uri><nome>Aelton Freitas</nome><siglaPartido>PP</siglaPartido><uriPartido>https://dadosabertos.camara.leg.br/api/v2/partidos/37903</uriPartido><siglaUf>MG</siglaUf><idLegislatura>56</idLegislatura><urlFoto>https://www.camara.leg.br/internet/deputado/bandep/141372.jpg</urlFoto><email/></deputado_><deputado_><id>160508</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/160508</uri><nome>Afonso Florence</nome><siglaPartido>PT</siglaPartido><uriPartido>https://dadosabertos.camara.leg.br/api/v2/partidos/36844</uriPartido><siglaUf>BA</siglaUf><idLegislatura>56</idLegislatura><urlFoto>https://www.camara.leg.br/internet/deputado/bandep/160508.jpg</urlFoto><email/></deputado_><deputado_><id>136811</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/136811</uri><nome>Afonso Hamm</nome><siglaPartido>PP</siglaPartido><uriPartido>https://dadosabertos.camara.leg.br/api/v2/partidos/37903</uriPartido><siglaUf>RS</siglaUf><idLegislatura>56</idLegislatura><urlFoto>https://www.camara.leg.br/internet/deputado/bandep/136811.jpg</urlFoto><email/></deputado_><deputado_><id>178835</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/178835</uri><nome>Afonso Motta</nome><siglaPartido>PDT</siglaPartido><uriPartido>https://dadosabertos.camara.leg.br/api/v2/partidos/36786</uriPartido><siglaUf>RS</siglaUf><idLegislatura>56</idLegislatura><urlFoto>https://www.camara.leg.br/internet/deputado/bandep/178835.jpg</urlFoto><email/></deputado_><deputado_><id>204495</id><uri>https://dadosabertos.camara.leg.br/api/v2/deputados/204495</uri><nome>Airton Fa ...

# %%
url = 'https://dadosabertos.camara.leg.br/api/v2/deputados' 
headers = {'accept': 'application/json'}
r = requests.get(url, headers=headers)
r.text
# Out:
# '{"dados":[{"id":204521,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/204521","nome":"Abou Anni","siglaPartido":"UNIÃO","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/38009","siglaUf":"SP","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/204521.jpg","email":null},{"id":204379,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/204379","nome":"Acácio Favacho","siglaPartido":"MDB","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/36899","siglaUf":"AP","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/204379.jpg","email":null},{"id":204560,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/204560","nome":"Adolfo Viana","siglaPartido":"PSDB","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/36835","siglaUf":"BA","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/204560.jpg","email":null},{"id":204528,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/204528","nome":"Adriana Ventura","siglaPartido":"NOVO","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/37901","siglaUf":"SP","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/204528.jpg","email":null},{"id":121948,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/121948","nome":"Adriano do Baldy","siglaPartido":"PP","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/37903","siglaUf":"GO","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/121948.jpg","email":null},{"id":74646,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/74646","nome":"Aécio Neves","siglaPartido":"PSDB","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/36835","siglaUf":"MG","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/74646.jpg","email":null},{"id":141372,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/141372","nome":"Aelton Freitas","siglaPartido":"PP","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/37903","siglaUf":"MG","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/141372.jpg","email":null},{"id":160508,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/160508","nome":"Afonso Florence","siglaPartido":"PT","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/36844","siglaUf":"BA","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/160508.jpg","email":null},{"id":136811,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/136811","nome":"Afonso Hamm","siglaPartido":"PP","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/37903","siglaUf":"RS","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/136811.jpg","email":null},{"id":178835,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/178835","nome":"Afonso Motta","siglaPartido":"PDT","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/36786","siglaUf":"RS","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/178835.jpg","email":null},{"id":204495,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/204495","nome":"Airton Faleiro","siglaPartido":"PT","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/36844","siglaUf":"PA","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/204495.jpg","email":null},{"id":204549,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/204549","nome":"AJ Albuquerque","siglaPartido":"PP","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/37903","siglaUf":"CE","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/204549.jpg","email":null},{"id":160559,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/160559","nome":"Alceu Moreira","siglaPartido":"MDB","uriPartido":"https://dadosabertos.camara.leg.br/api ...

# %%
for dep in list(r.json()['dados'])[:10]:
    print(dep['nome'])
# Out:
# Abou Anni
# Acácio Favacho
# Adolfo Viana
# Adriana Ventura
# Adriano do Baldy
# Aécio Neves
# Aelton Freitas
# Afonso Florence
# Afonso Hamm
# Afonso Motta

# %% [markdown]
# ## Passando parâmetros para a query string do Request

# %%
url = 'https://dadosabertos.camara.leg.br/api/v2/deputados' 
headers = {'accept': 'application/json'}
parametros = {'ordem': 'DESC', 'ordenarPor': 'nome'}
r = requests.get(url, headers=headers, params=parametros)
print(r.url)
r.text
# Out:
# https://dadosabertos.camara.leg.br/api/v2/deputados?ordem=DESC&ordenarPor=nome
# '{"dados":[{"id":160592,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/160592","nome":"Zeca Dirceu","siglaPartido":"PT","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/36844","siglaUf":"PR","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/160592.jpg","email":null},{"id":204517,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/204517","nome":"Zé Vitor","siglaPartido":"PL","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/37906","siglaUf":"MG","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/204517.jpg","email":null},{"id":160632,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/160632","nome":"Zé Silva","siglaPartido":"SOLIDARIEDADE","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/37904","siglaUf":"MG","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/160632.jpg","email":null},{"id":204559,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/204559","nome":"Zé Neto","siglaPartido":"PT","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/36844","siglaUf":"BA","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/204559.jpg","email":null},{"id":178889,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/178889","nome":"Zé Carlos","siglaPartido":"PT","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/36844","siglaUf":"MA","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/178889.jpg","email":null},{"id":74439,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/74439","nome":"Wolney Queiroz","siglaPartido":"PDT","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/36786","siglaUf":"PE","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/74439.jpg","email":null},{"id":74044,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/74044","nome":"Wilson Santiago","siglaPartido":"REPUBLICANOS","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/37908","siglaUf":"PB","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/74044.jpg","email":null},{"id":74043,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/74043","nome":"Wellington Roberto","siglaPartido":"PL","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/37906","siglaUf":"PB","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/74043.jpg","email":null},{"id":160518,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/160518","nome":"Weliton Prado","siglaPartido":"PROS","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/36763","siglaUf":"MG","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/160518.jpg","email":null},{"id":178952,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/178952","nome":"Walter Alves","siglaPartido":"MDB","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/36899","siglaUf":"RN","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/178952.jpg","email":null},{"id":160569,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/160569","nome":"Waldenor Pereira","siglaPartido":"PT","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/36844","siglaUf":"BA","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/160569.jpg","email":null},{"id":215044,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/215044","nome":"Vivi Reis","siglaPartido":"PSOL","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/partidos/36839","siglaUf":"PA","idLegislatura":56,"urlFoto":"https://www.camara.leg.br/internet/deputado/bandep/215044.jpg","email":null},{"id":178992,"uri":"https://dadosabertos.camara.leg.br/api/v2/deputados/178992","nome":"Vitor Lippi","siglaPartido":"PSDB","uriPartido":"https://dadosabertos.camara.leg.br/api/v2/part ...
