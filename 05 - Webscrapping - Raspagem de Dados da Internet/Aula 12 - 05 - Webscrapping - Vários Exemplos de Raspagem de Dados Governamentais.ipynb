# %% [markdown]
# # 05 - Webscrapping - Raspagem de Dados da Internet
# ## Aula 12 - 05 - Webscrapping - Vários Exemplos de Raspagem de Dados Governamentais

# %% [markdown]
# ## Professor: Orlando Oliveira dos Santos, MsC.
#  - E-mail: professor.orlando.santos@gmail.com
#  - Youtube :https://www.youtube.com/channel/UCPWWbkPWFmOjXH50TQWNAYg
#  - Linkedin: https://linkedin.com/in/orlandoosantos
#  - Facebook: https://www.facebook.com/proforlandosantosmsc/
#  - Twitter: https://twitter.com/ProfOrlandoMsC
#  - Instagram: https://www.instagram.com/proforlandosantosmsc/
#
#
#
# ## Formação Acadêmica
# - Mestrado em Computação Aplicada - UnB (2014 – 2016)
# - MBA, Administração Estratégica de Sistemas de Informação – FGV (2011 – 2013)
# - Tecnólogo em Processamento de Dados, Análise e Desenvolvimento de Sistemas – FAETEC/SP (2000-2002)

# %% [markdown]
# # Webscrapping - Vários Exemplos de Raspagem de Dados Governamentais

# %% [markdown]
# # Projeto de Análise de dados Completo
#
# Escopo
# Produzir uma análise de dados da Covid-19 no Brasil, integrando dados obtidos por raspagem de dados do Ministério da Saúde, do IBGE,e do Tesouro Nacional
# https://www.tesourotransparente.gov.br/temas/estados-e-municipios/transferencias-a-estados-e-municipios

# %%
import requests
import os

# %% [markdown]
# # Importar dados da Covid do Ministério da Saúde

# %%
link = "https://xx9p7hp1p7.execute-api.us-east-1.amazonaws.com/prod/PortalGeral"
header_text = '''authority: xx9p7hp1p7.execute-api.us-east-1.amazonaws.com"
sec-ch-ua: "Google Chrome";v="87", " Not;A Brand";v="99", "Chromium";v="87"
accept: application/json, text/plain, */*
x-parse-application-id: unAFkcaNDeXajurGB7LChj8SgQYS2ptm
sec-ch-ua-mobile: ?0
user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36
origin: https://covid.saude.gov.br
sec-fetch-site: cross-site
sec-fetch-mode: cors
sec-fetch-dest: empty
referer: https://covid.saude.gov.br/
accept-language: pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7,he-IL;q=0.6,he;q=0.5,el-GR;q=0.4,el;q=0.3,zh-CN;q=0.2,zh;q=0.1
'''
headerdict = { x.split(':')[0].strip() :  x.split(':')[1].strip()for x in header_text.splitlines()}
r = requests.get(link, headers=headerdict)
 
json_covid = r.json()

# %%
json_covid
# Out:
# {'results': [{'arquivo': {'__type': 'File',
#     'name': '7253f6a45fa9a71fb309ef32a07a2ae7_HIST_PAINEL_COVIDBR_18dez2020.csv',
#     'url': 'https://mobileapps.saude.gov.br/esus-vepi/files/unAFkcaNDeXajurGB7LChj8SgQYS2ptm/7253f6a45fa9a71fb309ef32a07a2ae7_HIST_PAINEL_COVIDBR_18dez2020.csv'},
#    'arquivo_srag': {'__type': 'File',
#     'name': '0f7290d807e00e3dfe98197d2586f1c2_arquivo_srag20200420.csv',
#     'url': 'https://mobileapps.saude.gov.br/esus-vepi/files/unAFkcaNDeXajurGB7LChj8SgQYS2ptm/0f7290d807e00e3dfe98197d2586f1c2_arquivo_srag20200420.csv'},
#    'createdAt': '2020-03-25T16:28:25.593Z',
#    'dt_atualizacao': '18/12/2020 18:30',
#    'dt_atualizacao_srag': '16/12/2020 18:00',
#    'objectId': 'HXxFBK2BTx',
#    'texto_rodape': 'HIST_PAINEL_COVIDBR_18dez2020.csv',
#    'total_confirmado': '162.699',
#    'total_letalidade': '6,8%',
#    'total_obitos': '11.123',
#    'updatedAt': '2020-12-18T21:42:42.888Z',
#    'versao': 'v2.0'}]}

# %%
metadados = json_covid['results'][0]
for item in metadados.items():
  print(item)
# Out:
# ('objectId', 'HXxFBK2BTx')
# ('total_confirmado', '162.699')
# ('createdAt', '2020-03-25T16:28:25.593Z')
# ('updatedAt', '2020-12-18T21:42:42.888Z')
# ('total_obitos', '11.123')
# ('versao', 'v2.0')
# ('dt_atualizacao', '18/12/2020 18:30')
# ('total_letalidade', '6,8%')
# ('arquivo_srag', {'__type': 'File', 'name': '0f7290d807e00e3dfe98197d2586f1c2_arquivo_srag20200420.csv', 'url': 'https://mobileapps.saude.gov.br/esus-vepi/files/unAFkcaNDeXajurGB7LChj8SgQYS2ptm/0f7290d807e00e3dfe98197d2586f1c2_arquivo_srag20200420.csv'})
# ('texto_rodape', 'HIST_PAINEL_COVIDBR_18dez2020.csv')
# ('arquivo', {'__type': 'File', 'name': '7253f6a45fa9a71fb309ef32a07a2ae7_HIST_PAINEL_COVIDBR_18dez2020.csv', 'url': 'https://mobileapps.saude.gov.br/esus-vepi/files/unAFkcaNDeXajurGB7LChj8SgQYS2ptm/7253f6a45fa9a71fb309ef32a07a2ae7_HIST_PAINEL_COVIDBR_18dez2020.csv'})
# ('dt_atualizacao_srag', '16/12/2020 18:00')

# %%
nome_arquivo_covid = metadados['texto_rodape']
print(nome_arquivo_covid)
link_arquivo = metadados['arquivo']['url']
print(link_arquivo)
# Out:
# HIST_PAINEL_COVIDBR_18dez2020.csv
# https://mobileapps.saude.gov.br/esus-vepi/files/unAFkcaNDeXajurGB7LChj8SgQYS2ptm/7253f6a45fa9a71fb309ef32a07a2ae7_HIST_PAINEL_COVIDBR_18dez2020.csv

# %%
r = requests.get(link_arquivo)
for data in list(r.iter_content(chunk_size=100))[:10]:
  print(data)
# Out:
# b'regiao;estado;municipio;coduf;codmun;codRegiaoSaude;nomeRegiaoSaude;data;semanaEpi;populacaoTCU2019;'
# b'casosAcumulado;casosNovos;obitosAcumulado;obitosNovos;Recuperadosnovos;emAcompanhamentoNovos;interio'
# b'r/metropolitana\r\nBrasil;;;76;;;;2020-02-25;9;210147125;0;0;0;0;;;\r\nBrasil;;;76;;;;2020-02-26;9;21014'
# b'7125;1;1;0;0;;;\r\nBrasil;;;76;;;;2020-02-27;9;210147125;1;0;0;0;;;\r\nBrasil;;;76;;;;2020-02-28;9;21014'
# b'7125;1;0;0;0;;;\r\nBrasil;;;76;;;;2020-02-29;9;210147125;2;1;0;0;;;\r\nBrasil;;;76;;;;2020-03-01;10;2101'
# b'47125;2;0;0;0;;;\r\nBrasil;;;76;;;;2020-03-02;10;210147125;2;0;0;0;;;\r\nBrasil;;;76;;;;2020-03-03;10;21'
# b'0147125;2;0;0;0;;;\r\nBrasil;;;76;;;;2020-03-04;10;210147125;3;1;0;0;;;\r\nBrasil;;;76;;;;2020-03-05;10;'
# b'210147125;7;4;0;0;;;\r\nBrasil;;;76;;;;2020-03-06;10;210147125;13;6;0;0;;;\r\nBrasil;;;76;;;;2020-03-07;'
# b'10;210147125;19;6;0;0;;;\r\nBrasil;;;76;;;;2020-03-08;11;210147125;25;6;0;0;;;\r\nBrasil;;;76;;;;2020-03'
# b'-09;11;210147125;25;0;0;0;;;\r\nBrasil;;;76;;;;2020-03-10;11;210147125;34;9;0;0;;;\r\nBrasil;;;76;;;;202'

# %%
with open(nome_arquivo_covid, 'wb') as f:
  f.write(r.content)

# %%
with open(nome_arquivo_covid, 'r') as f:
  lines = f.readlines()

for line in lines[:10]:
  print('l-',line)
# Out:
# l- regiao;estado;municipio;coduf;codmun;codRegiaoSaude;nomeRegiaoSaude;data;semanaEpi;populacaoTCU2019;casosAcumulado;casosNovos;obitosAcumulado;obitosNovos;Recuperadosnovos;emAcompanhamentoNovos;interior/metropolitana
#
# l- Brasil;;;76;;;;2020-02-25;9;210147125;0;0;0;0;;;
#
# l- Brasil;;;76;;;;2020-02-26;9;210147125;1;1;0;0;;;
#
# l- Brasil;;;76;;;;2020-02-27;9;210147125;1;0;0;0;;;
#
# l- Brasil;;;76;;;;2020-02-28;9;210147125;1;0;0;0;;;
#
# l- Brasil;;;76;;;;2020-02-29;9;210147125;2;1;0;0;;;
#
# l- Brasil;;;76;;;;2020-03-01;10;210147125;2;0;0;0;;;
#
# l- Brasil;;;76;;;;2020-03-02;10;210147125;2;0;0;0;;;
#
# l- Brasil;;;76;;;;2020-03-03;10;210147125;2;0;0;0;;;
#
# l- Brasil;;;76;;;;2020-03-04;10;210147125;3;1;0;0;;;

# %% [markdown]
# ### Criar o dataframe usando o read_csv

# %%
dfcovid.head()
# Out:
#    regiao estado  ... emAcompanhamentoNovos  interior/metropolitana
# 0  Brasil    NaN  ...                   NaN                     NaN
# 1  Brasil    NaN  ...                   NaN                     NaN
# 2  Brasil    NaN  ...                   NaN                     NaN
# 3  Brasil    NaN  ...                   NaN                     NaN
# 4  Brasil    NaN  ...                   NaN                     NaN
#
# [5 rows x 17 columns]

# %%
import pandas as pd
dfcovid = pd.read_csv(nome_arquivo_covid, sep=';')
dfcovid.head()
# Out:
#    regiao estado  ... emAcompanhamentoNovos  interior/metropolitana
# 0  Brasil    NaN  ...                   NaN                     NaN
# 1  Brasil    NaN  ...                   NaN                     NaN
# 2  Brasil    NaN  ...                   NaN                     NaN
# 3  Brasil    NaN  ...                   NaN                     NaN
# 4  Brasil    NaN  ...                   NaN                     NaN
#
# [5 rows x 17 columns]

# %% [markdown]
# # Downloads das transferências da União para os Estados do Tesouro Nacional

# %%
link = 'https://sisweb.tesouro.gov.br/apex/f?p=2600:1::IR%5Brelatorio-transferencias-estados%5D_CSV::::'
header_text = '''Host: sisweb.tesouro.gov.br
Connection: keep-alive
sec-ch-ua: "Google Chrome";v="87", " Not;A Brand";v="99", "Chromium";v="87"
sec-ch-ua-mobile: ?0
Upgrade-Insecure-Requests: 1
User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36
Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9
Sec-Fetch-Site: same-origin
Sec-Fetch-Mode: navigate
Sec-Fetch-User: ?1
Sec-Fetch-Dest: document
Referer: https://sisweb.tesouro.gov.br/apex/f?p=2600:1::IR_962295:NO:::
Accept-Encoding: gzip, deflate, br
Accept-Language: pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7,he-IL;q=0.6,he;q=0.5,el-GR;q=0.4,el;q=0.3,zh-CN;q=0.2,zh;q=0.1
'''

headerdict = { x.split(':')[0].strip() :  x.split(':')[1].strip()for x in header_text.splitlines()}
r = requests.get(link, headers=headerdict)

# %%
r.content
# Out:
# b'"Regiao";"UF";"Ano";"Transfer\xeancia";"Valor Consolidado"\n"Centro-Oeste";"DF";"1997";"FPE";"R$67.670.060,55"\n"Centro-Oeste";"DF";"1997";"IPI-Exp";"R$108.291,80"\n"Centro-Oeste";"DF";"1998";"FPE";"R$64.066.428,82"\n"Centro-Oeste";"DF";"1998";"FUNDEF";"R$16.684.000,33"\n"Centro-Oeste";"DF";"1998";"IPI-Exp";"R$16.803,94"\n"Centro-Oeste";"DF";"1999";"FPE";"R$70.955.915,95"\n"Centro-Oeste";"DF";"1999";"FUNDEF";"R$18.521.578,84"\n"Centro-Oeste";"DF";"1999";"IPI-Exp";"R$29.579,04"\n"Centro-Oeste";"DF";"2000";"FPE";"R$84.083.329,09"\n"Centro-Oeste";"DF";"2000";"FUNDEF";"R$23.630.388,18"\n"Centro-Oeste";"DF";"2000";"IPI-Exp";"R$42.407,24"\n"Centro-Oeste";"DF";"2000";"LC 87/96 (Lei Kandir)";"R$18.714.587,63"\n"Centro-Oeste";"DF";"2001";"FPE";"R$98.950.508,72"\n"Centro-Oeste";"DF";"2001";"FUNDEF";"R$27.932.254,89"\n"Centro-Oeste";"DF";"2001";"IPI-Exp";"R$92.443,20"\n"Centro-Oeste";"DF";"2001";"LC 87/96 (Lei Kandir)";"R$24.650.876,52"\n"Centro-Oeste";"DF";"2001";"Royalties";"R$1,57"\n"Centro-Oeste";"DF";"2002";"FPE";"R$122.459.560,22"\n"Centro-Oeste";"DF";"2002";"FUNDEF";"R$34.322.421,20"\n"Centro-Oeste";"DF";"2002";"IPI-Exp";"R$36.109,76"\n"Centro-Oeste";"DF";"2002";"LC 87/96 (Lei Kandir)";"R$27.205.450,08"\n"Centro-Oeste";"DF";"2002";"Royalties";"R$20.690,07"\n"Centro-Oeste";"DF";"2003";"FPE";"R$127.395.104,34"\n"Centro-Oeste";"DF";"2003";"FUNDEF";"R$33.710.926,67"\n"Centro-Oeste";"DF";"2003";"IPI-Exp";"R$46.186,86"\n"Centro-Oeste";"DF";"2003";"LC 87/96 (Lei Kandir)";"R$22.178.812,59"\n"Centro-Oeste";"DF";"2003";"Royalties";"R$77.203,97"\n"Centro-Oeste";"DF";"2004";"CIDE-Combust\xedveis";"R$15.861.496,48"\n"Centro-Oeste";"DF";"2004";"FEX";"R$297.600,00"\n"Centro-Oeste";"DF";"2004";"FPE";"R$140.425.003,08"\n"Centro-Oeste";"DF";"2004";"FUNDEF";"R$36.562.195,68"\n"Centro-Oeste";"DF";"2004";"IPI-Exp";"R$109.918,60"\n"Centro-Oeste";"DF";"2004";"LC 87/96 (Lei Kandir)";"R$23.401.775,04"\n"Centro-Oeste";"DF";"2004";"Royalties";"R$296.993,95"\n"Centro-Oeste";"DF";"2005";"CIDE-Combust\xedveis";"R$24.247.094,89"\n"Centro-Oeste";"DF";"2005";"FEX";"R$148.800,00"\n"Centro-Oeste";"DF";"2005";"FPE";"R$175.749.090,54"\n"Centro-Oeste";"DF";"2005";"FUNDEF";"R$45.673.494,79"\n"Centro-Oeste";"DF";"2005";"IPI-Exp";"R$577.694,62"\n"Centro-Oeste";"DF";"2005";"LC 87/96 (Lei Kandir)";"R$23.401.775,04"\n"Centro-Oeste";"DF";"2005";"Royalties";"R$481.545,15"\n"Centro-Oeste";"DF";"2006";"CIDE-Combust\xedveis";"R$24.095.990,35"\n"Centro-Oeste";"DF";"2006";"FEX";"R$2.430.900,00"\n"Centro-Oeste";"DF";"2006";"FPE";"R$194.504.644,63"\n"Centro-Oeste";"DF";"2006";"FUNDEF";"R$47.847.476,04"\n"Centro-Oeste";"DF";"2006";"IPI-Exp";"R$1.021.732,35"\n"Centro-Oeste";"DF";"2006";"LC 87/96 (Lei Kandir)";"R$13.421.606,27"\n"Centro-Oeste";"DF";"2006";"Royalties";"R$544.446,16"\n"Centro-Oeste";"DF";"2007";"CIDE-Combust\xedveis";"R$25.951.401,73"\n"Centro-Oeste";"DF";"2007";"FEX";"R$0,00"\n"Centro-Oeste";"DF";"2007";"FPE";"R$220.930.919,51"\n"Centro-Oeste";"DF";"2007";"FUNDEB";"R$61.008.276,41"\n"Centro-Oeste";"DF";"2007";"IPI-Exp";"R$1.660.687,78"\n"Centro-Oeste";"DF";"2007";"LC 87/96 (Lei Kandir)";"R$13.159.490,24"\n"Centro-Oeste";"DF";"2007";"Royalties";"R$628.786,63"\n"Centro-Oeste";"DF";"2008";"CIDE-Combust\xedveis";"R$22.462.097,91"\n"Centro-Oeste";"DF";"2008";"FEX";"R$7.180.159,99"\n"Centro-Oeste";"DF";"2008";"FPE";"R$264.695.098,80"\n"Centro-Oeste";"DF";"2008";"FUNDEB";"R$77.841.755,13"\n"Centro-Oeste";"DF";"2008";"IPI-Exp";"R$2.318.571,02"\n"Centro-Oeste";"DF";"2008";"LC 87/96 (Lei Kandir)";"R$12.895.795,18"\n"Centro-Oeste";"DF";"2008";"Royalties";"R$682.598,02"\n"Centro-Oeste";"DF";"2009";"CIDE-Combust\xedveis";"R$13.691.640,07"\n"Centro-Oeste";"DF";"2009";"FEX";"R$0,00"\n"Centro-Oeste";"DF";"2009";"FPE";"R$249.896.651,74"\n"Centro-Oeste";"DF";"2009";"FUNDEB";"R$81.756.175,52"\n"Centro-Oeste";"DF";"2009";"IPI-Exp";"R$2.245.356,27"\n"Centro-Oeste";"DF";"2009";"LC 87/96 (Lei Kandir)";"R$12.632.100,00"\n"Centro-Oeste";"DF";"2009";"Royalties";"R$783.392,44"\n"Centro-Oeste";" ...

# %%
nome_arquivo_transferencias = 'transferencias_estados.csv'
with open(nome_arquivo_transferencias, 'wb') as f:
  f.write(r.content)

dir = os.getcwd()
print( os.listdir(dir))
# Out:
# ['.config', 'HIST_PAINEL_COVIDBR_18dez2020.csv', 'transferencias_estados.csv', 'sample_data']

# %%
with open(nome_arquivo_transferencias, 'r', encoding='cp1252') as f:
  lines = f.readlines()

for line in lines[:10]:
  print(line)
# Out:
# "Regiao";"UF";"Ano";"Transferência";"Valor Consolidado"
#
# "Centro-Oeste";"DF";"1997";"FPE";"R$67.670.060,55"
#
# "Centro-Oeste";"DF";"1997";"IPI-Exp";"R$108.291,80"
#
# "Centro-Oeste";"DF";"1998";"FPE";"R$64.066.428,82"
#
# "Centro-Oeste";"DF";"1998";"FUNDEF";"R$16.684.000,33"
#
# "Centro-Oeste";"DF";"1998";"IPI-Exp";"R$16.803,94"
#
# "Centro-Oeste";"DF";"1999";"FPE";"R$70.955.915,95"
#
# "Centro-Oeste";"DF";"1999";"FUNDEF";"R$18.521.578,84"
#
# "Centro-Oeste";"DF";"1999";"IPI-Exp";"R$29.579,04"
#
# "Centro-Oeste";"DF";"2000";"FPE";"R$84.083.329,09"

# %%
dftransferencias = pd.read_csv(nome_arquivo_transferencias, sep=';', encoding='cp1252')
dftransferencias.head()
# Out:
#          Regiao  UF   Ano Transferência Valor Consolidado
# 0  Centro-Oeste  DF  1997           FPE   R$67.670.060,55
# 1  Centro-Oeste  DF  1997       IPI-Exp      R$108.291,80
# 2  Centro-Oeste  DF  1998           FPE   R$64.066.428,82
# 3  Centro-Oeste  DF  1998        FUNDEF   R$16.684.000,33
# 4  Centro-Oeste  DF  1998       IPI-Exp       R$16.803,94

# %% [markdown]
# # Download dos dados de PIB a preços correntes dos estados do site do IBGE
#
# #### Usar o construtor de consultas da API de agregados do IBGE para criar a url desejada
# - endereço de construtor de consultas da API: https://servicodados.ibge.gov.br/api/docs/agregados?versao=3#api-bq
#
#
# #### Acessar o conteúdo usando o requests

# %%
import requests
import json
url = 'https://servicodados.ibge.gov.br/api/v3/agregados/5938/periodos/2002|2003|2004|2005|2006|2007|2008|2009|2010|2011|2012|2013|2014|2015|2016|2017/variaveis/37?localidades=N3[all]'
r = requests.get(url)
json_agregado_pib_estadual = r.json()

# %%
nome_arquivo_pib = 'ibge_pib.json'
with open(nome_arquivo_pib, 'w') as f:
    json.dump(json_agregado_pib_estadual, f)

# %%
dadospib = []
for serie in json_agregado_pib_estadual[0]['resultados'][0]['series']:
  estado = {}
  estado['id_codigo_ibge'] = serie['localidade']['id']
  estado['uf_nome'] = serie['localidade']['nome']
  for pibano, pibvalor in serie['serie'].items():
    estado[pibano] = pibvalor
  dadospib.append(estado)
dadospib[0]
# Out:
# {'2002': '7467630',
#  '2003': '9425010',
#  '2004': '11004641',
#  '2005': '12511821',
#  '2006': '13054713',
#  '2007': '14438376',
#  '2008': '17285542',
#  '2009': '19725010',
#  '2010': '23907887',
#  '2011': '27574714',
#  '2012': '30112720',
#  '2013': '31121413',
#  '2014': '34030982',
#  '2015': '36563333',
#  '2016': '39460359',
#  '2017': '43516147',
#  'id_codigo_ibge': '11',
#  'uf_nome': 'Rondônia'}

# %%
dfpib = pd.DataFrame(dadospib)
dfpib.head()
# Out:
#   id_codigo_ibge   uf_nome      2002  ...       2015       2016       2017
# 0             11  Rondônia   7467630  ...   36563333   39460359   43516147
# 1             12      Acre   2971301  ...   13622802   13754240   14272941
# 2             13  Amazonas  22093338  ...   86568184   89039782   93240191
# 3             14   Roraima   2392033  ...   10242905   11013237   12104709
# 4             15      Pará  26482159  ...  130899505  138107514  155232404
#
# [5 rows x 18 columns]

# %% [markdown]
# # Download dos dados de população estimada dos estados da api do IBGE

# %%
import requests
url = 'https://servicodados.ibge.gov.br/api/v3/agregados/6579/periodos/2001|2002|2003|2004|2005|2006|2008|2009|2011|2012|2013|2014|2015|2016|2017|2018|2019|2020/variaveis/9324?localidades=N3[all]'
r = requests.get(url)
json_agregado_pop_estadual = r.json()

# %%
nome_arquivo_populacao = 'ibge_populacao.json'
with open(nome_arquivo_pib, 'w') as f:
    json.dump(json_agregado_pop_estadual, f)

# %%
json_agregado_pop_estadual[0]['resultados'][0]['series'][0]
# Out:
# {'localidade': {'id': '11',
#   'nivel': {'id': 'N3', 'nome': 'Unidade da Federação'},
#   'nome': 'Rondônia'},
#  'serie': {'2001': '1407886',
#   '2002': '1431777',
#   '2003': '1455907',
#   '2004': '1562085',
#   '2005': '1534594',
#   '2006': '1562417',
#   '2008': '1493565',
#   '2009': '1503928',
#   '2011': '1576455',
#   '2012': '1590011',
#   '2013': '1728214',
#   '2014': '1748531',
#   '2015': '1768204',
#   '2016': '1787279',
#   '2017': '1805788',
#   '2018': '1757589',
#   '2019': '1777225',
#   '2020': '1796460'}}

# %%
dadospopulacao = []
for serie in json_agregado_pop_estadual[0]['resultados'][0]['series']:
  estado = {}
  estado['id_codigo_ibge'] = serie['localidade']['id']
  estado['uf_nome'] = serie['localidade']['nome']
  for populacaoano, populacaovalor in serie['serie'].items():
    estado[populacaoano] = populacaovalor
  dadospopulacao.append(estado)
dadospopulacao[0]
# Out:
# {'2001': '1407886',
#  '2002': '1431777',
#  '2003': '1455907',
#  '2004': '1562085',
#  '2005': '1534594',
#  '2006': '1562417',
#  '2008': '1493565',
#  '2009': '1503928',
#  '2011': '1576455',
#  '2012': '1590011',
#  '2013': '1728214',
#  '2014': '1748531',
#  '2015': '1768204',
#  '2016': '1787279',
#  '2017': '1805788',
#  '2018': '1757589',
#  '2019': '1777225',
#  '2020': '1796460',
#  'id_codigo_ibge': '11',
#  'uf_nome': 'Rondônia'}

# %%
dfpopulacao = pd.DataFrame(dadospopulacao)
dfpopulacao.head()
# Out:
#   id_codigo_ibge   uf_nome     2001  ...     2018     2019     2020
# 0             11  Rondônia  1407886  ...  1757589  1777225  1796460
# 1             12      Acre   574355  ...   869265   881935   894470
# 2             13  Amazonas  2900240  ...  4080611  4144597  4207714
# 3             14   Roraima   337237  ...   576568   605761   631181
# 4             15      Pará  6341736  ...  8513497  8602865  8690745
#
# [5 rows x 20 columns]

# %% [markdown]
# # Download dos dados da página do IBGE Cidades e Estados
#
# https://www.ibge.gov.br/cidades-e-estados

# %%
link = "https://www.ibge.gov.br/cidades-e-estados"
header_text = '''Host: www.ibge.gov.br
Connection: keep-alive
Content-Length: 130
sec-ch-ua: "Google Chrome";v="87", " Not;A Brand";v="99", "Chromium";v="87"
Accept: */*
X-Requested-With: XMLHttpRequest
sec-ch-ua-mobile: ?0
User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36
Content-Type: application/x-www-form-urlencoded; charset=UTF-8
Origin: https://www.ibge.gov.br
Sec-Fetch-Site: same-origin
Sec-Fetch-Mode: cors
Sec-Fetch-Dest: empty
Referer: https://www.ibge.gov.br/cidades-e-estados
Accept-Encoding: gzip, deflate, br
Accept-Language: pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7,he-IL;q=0.6,he;q=0.5,el-GR;q=0.4,el;q=0.3,zh-CN;q=0.2,zh;q=0.1
Cookie: aef8fa09908b26bad991ae1459a80b72=pt-BR; _ga=GA1.3.2091996607.1603766038; d9d2177675fdebc6cb80bc5e949fd874=ijf3iph4194vlnudiau0bbq6i6; ROUTEID=.www4; _gid=GA1.3.1201619511.1607833020; _gat_gtag_UA_285486_1=1; _gat_gtag_UA_285486_76=1
'''
headerdict = { x.split(':')[0].strip() :  x.split(':')[1].strip()for x in header_text.splitlines()}

dados_text = '''ask: exportData
formato: csv
tipo: estados
view: exportacao
format: raw
codigo: xx
municipio: Brasil
b28bf8b221a274fd1f63acda16468017: 1
'''
datadict = { x.split(':')[0].strip() :  x.split(':')[1].strip()for x in dados_text.splitlines()}

r = requests.post(link, headers=headerdict, data=datadict )

# %%
r.content
# Out:
# b'Estados do Brasil\nUF [-],C&oacute;digo [-],Gent&iacute;lico [-],Governador [2019],Capital [2010],&Aacute;rea Territorial - km&sup2; [2019],Popula&ccedil;&atilde;o estimada - pessoas [2020],Densidade demogr&aacute;fica - hab/km&sup2; [2010],Matri\xcc\x81culas no ensino fundamental - matr&iacute;culas [2018],IDH &lt;span&gt;I\xcc\x81ndice de desenvolvimento humano&lt;/span&gt; [2010],Receitas realizadas - R$ (&times;1000) [2017],Despesas empenhadas - R$ (&times;1000) [2017],Rendimento mensal domiciliar per capita - R$ [2019],Total de ve&iacute;culos - ve&iacute;culos [2018],\nAcre,12,acriano,GLADSON DE LIMA CAMELI,Rio Branco,164123.964,894470,4.47,157646,0.663,6632883.10836,6084416.8063,890,277831,\nAlagoas,27,alagoano,JOSE RENAN VASCONCELOS CALHEIROS FILHO,Macei&oacute;,27843.295,3351543,112.33,490587,0.631,11950438.46015,10460634.91711,731,834827,\nAmap&aacute;,16,amapaense,ANTONIO WALDEZ G&Oacute;ES DA SILVA,Macap&aacute;,142470.762,861773,4.69,136185,0.708,5396417.14471,4224464.08829,880,195039,\nAmazonas,13,amazonense,WILSON MIRANDA LIMA,Manaus,1559167.889,4207714,2.23,705007,0.674,17328459.43402,15324896.55705,842,883083,\nBahia,29,baiano,RUI COSTA DOS SANTOS,Salvador,564760.427,14930634,24.82,2034711,0.660,50191003.24052,45570160.0038,913,4139107,\nCear&aacute;,23,cearense,CAMILO SOBREIRA DE SANTANA,Fortaleza,148894.441,9187103,56.76,1198116,0.682,28420222.47191,24608352.18276,942,3148369,\nDistrito Federal,53,brasiliense,IBANEIS ROCHA BARROS JUNIOR,Bras&iacute;lia,5760.783,3055149,444.66,377622,0.824,23812211.27074,21990464.6849,2686,1812473,\nEsp&iacute;rito Santo,32,capixaba ou esp&iacute;rito-santense,JOSE RENATO CASAGRANDE,Vit&oacute;ria,46074.447,4064052,76.25,502059,0.740,19685616.74376,14392338.00188,1477,1936862,\nGoi&aacute;s,52,goiano,RONALDO RAMOS CAIADO,Goi&acirc;nia,340203.329,7113540,17.65,877593,0.735,37885335.16848,24248380.34233,1306,3909429,\nMaranh&atilde;o,21,maranhense,FL&Aacute;VIO DINO DE CASTRO E COSTA,S&atilde;o Lu&iacute;s,329642.182,7114598,19.81,1178949,0.639,18503261.35491,17627170.75574,636,1696683,\nMato Grosso,51,mato-grossense,MAURO MENDES FERREIRA,Cuiab&aacute;,903207.019,3526220,3.36,471613,0.725,23958528.83588,18187363.27009,1403,2080848,\nMato Grosso do Sul,50,sul-mato-grossense ou mato-grossense-do-sul,REINALDO AZAMBUJA SILVA,Campo Grande,357145.534,2809394,6.86,404114,0.729,16396655.77012,14506915.37404,1514,1583142,\nMinas Gerais,31,mineiro,ROMEU ZEMA NETO,Belo Horizonte,586521.123,21292666,33.41,2511483,0.731,97199823.15616,98391669.16323,1358,11191341,\nPar&aacute;,15,paraense,HELDER ZAHLUTH BARBALHO,Bel&eacute;m,1245870.798,8690745,6.07,1439788,0.646,25849446.10454,22533470.04547,807,2013952,\nPara&iacute;ba,25,paraibano,JO&Atilde;O AZEVEDO LINS FILHO,Jo&atilde;o Pessoa,56467.242,4039277,66.70,556248,0.658,13097005.31928,10074700.04266,929,1293668,\nParan&aacute;,41,paranaense,CARLOS ROBERTO MASSA JUNIOR,Curitiba,199298.979,11516840,52.40,1427218,0.749,60163576.12246,55534402.97483,1621,7571122,\nPernambuco,26,pernambucano,PAULO HENRIQUE SARAIVA C&Acirc;MARA,Recife,98067.881,9616621,89.62,1301930,0.673,35746028.97102,33320486.44445,970,3010638,\nPiau&iacute;,22,piauiense,JOS&Eacute; WELLINGTON BARROSO DE ARA&Uacute;JO DIAS,Teresina,251756.515,3281480,12.40,480126,0.646,12124215.61511,9676736.31835,827,1196192,\nRio de Janeiro,33,fluminense,WILSON JOS&Eacute; WITZEL,Rio de Janeiro,43750.427,17366189,365.23,2003315,0.761,78488140.78862,67965548.69757,1882,6725822,\nRio Grande do Norte,24,potiguar ou  norte-rio-grandense ou  rio-grandense-do-norte,MARIA DE FATIMA BEZERRA,Natal,52809.602,3534165,59.99,467629,0.684,13527552.73159,11330957.55333,1057,1290903,\nRio Grande do Sul,43,ga&uacute;cho ou sul-rio-grandense,EDUARDO FIGUEIREDO CAVALHEIRO LEITE,Porto Alegre,281707.156,11422973,37.96,1298736,0.746,66397468.17915,62476279.34364,1843,7077972,\nRond&ocirc;nia,11,rondoniense ou rondoniano,MARCOS JOSE ROCHA DOS SANTOS,Porto Velho,237765.240,1796460,6.58,269626,0.690,9122310.72305,7 ...

# %%
import html
nome_arquivo_ibge_estados = 'ibge_estados.csv'
with open(nome_arquivo_ibge_estados, 'w') as f:
  f.write(html.unescape(r.text))

# %%
with open(nome_arquivo_ibge_estados, 'r') as f:
  lines = f.readlines()

for line in lines[:10]:
  print(line)
# Out:
# Estados do Brasil
#
# UF [-],Código [-],Gentílico [-],Governador [2019],Capital [2010],Área Territorial - km² [2019],População estimada - pessoas [2020],Densidade demográfica - hab/km² [2010],Matrículas no ensino fundamental - matrículas [2018],IDH <span>Índice de desenvolvimento humano</span> [2010],Receitas realizadas - R$ (×1000) [2017],Despesas empenhadas - R$ (×1000) [2017],Rendimento mensal domiciliar per capita - R$ [2019],Total de veículos - veículos [2018],
#
# Acre,12,acriano,GLADSON DE LIMA CAMELI,Rio Branco,164123.964,894470,4.47,157646,0.663,6632883.10836,6084416.8063,890,277831,
#
# Alagoas,27,alagoano,JOSE RENAN VASCONCELOS CALHEIROS FILHO,Maceió,27843.295,3351543,112.33,490587,0.631,11950438.46015,10460634.91711,731,834827,
#
# Amapá,16,amapaense,ANTONIO WALDEZ GÓES DA SILVA,Macapá,142470.762,861773,4.69,136185,0.708,5396417.14471,4224464.08829,880,195039,
#
# Amazonas,13,amazonense,WILSON MIRANDA LIMA,Manaus,1559167.889,4207714,2.23,705007,0.674,17328459.43402,15324896.55705,842,883083,
#
# Bahia,29,baiano,RUI COSTA DOS SANTOS,Salvador,564760.427,14930634,24.82,2034711,0.660,50191003.24052,45570160.0038,913,4139107,
#
# Ceará,23,cearense,CAMILO SOBREIRA DE SANTANA,Fortaleza,148894.441,9187103,56.76,1198116,0.682,28420222.47191,24608352.18276,942,3148369,
#
# Distrito Federal,53,brasiliense,IBANEIS ROCHA BARROS JUNIOR,Brasília,5760.783,3055149,444.66,377622,0.824,23812211.27074,21990464.6849,2686,1812473,
#
# Espírito Santo,32,capixaba ou espírito-santense,JOSE RENATO CASAGRANDE,Vitória,46074.447,4064052,76.25,502059,0.740,19685616.74376,14392338.00188,1477,1936862,

# %%
nome_arquivo_ibge_estados
# Out:
# 'ibge_estados.csv'

# %%
lines[30]
# Out:
# '<table class="fontes-container"><tr><th>Notas:</th></tr><tr><td>População estimada: Diferença de 780 pessoas entre os Estados do Piauí e Ceará com relação a Projeção da População para o Brasil e Unidades da Federação 2019, para o ano de 2019, em virtude de alteração de limites entre municípios na fronteira interestadual. <br />Diferença de 446 pessoas entre os Estados de Alagoas e Pernambuco com relação a Projeção da População para o Brasil e Unidades da Federação 2019, para o ano de 2019, em virtude de alteração de limites entre municípios na fronteira interestadual. <br />Diferença de 206 pessoas entre os Estados de Sergipe e Bahia com relação a Projeção da População para o Brasil e Unidades da Federação 2019, para o ano de 2019, em virtude de alteração de limites entre municípios na fronteira interestadual. <br />Diferença de 2.250 pessoas entre o Estado de Goiás e o Distrito Federal com relação a Projeção da População para o Brasil e Unidades da Federação 2019, para o ano de 2019, em virtude de alteração de limites entre municípios na fronteira interestadual.</td></tr><tr><td>Rendimento mensal domiciliar per capita: As estimativas de rendimento apresentadas atendem ao disposto na Lei Complementar 143/2013, que estabelece os novos critérios de rateio do Fundo de Participação dos Estados e do Distrito Federal (FPE) e, em consequência, aos compromissos assumidos quanto à definição dos valores a serem repassados ao Tribunal de Contas da União (TCU) para o cálculo dos fatores representativos do inverso da renda domiciliar per capita</td></tr><tr><th>Fontes:</th></tr><tr><td>Área Territorial: Área territorial brasileira. Rio de Janeiro: IBGE, 2018</td></tr><tr><td>População estimada: IBGE, Diretoria de Pesquisas, Coordenação de População e Indicadores Sociais, Estimativas da população residente com data de referência 1o de julho de 2019</td></tr><tr><td>Densidade demográfica: IBGE, Censo Demográfico 2010, Área territorial brasileira. Rio de Janeiro: IBGE, 2011</td></tr><tr><td>IDH <span>Índice de desenvolvimento humano</span>: Programa das Nações Unidas para o Desenvolvimento - PNUD</td></tr><tr><td>Matrículas no ensino fundamental: Ministério da Educação, Instituto Nacional de Estudos e Pesquisas Educacionais - INEP - 2018</td></tr><tr><td>Total de veículos: Ministério das Cidades, Departamento Nacional de Trânsito - DENATRAN - 2018</td></tr><tr><td>Receitas realizadas: Contas anuais. Receitas orçamentárias realizadas (Anexo I-C) 2017 e Despesas orçamentárias empenhadas (Anexo I-D) 2017. In: Brasil. Secretaria do Tesouro Nacional, Siconfi: Sistema de Informações Contábeis e Fiscais do Setor Público Brasileiro. Brasília, DF, [2018]. Disponível em: https://siconfi.tesouro.gov.br/siconfi/pages/public/consulta_finbra/finbra_list.jsf. Acesso em: set. 2018</td></tr><tr><td>Despesas empenhadas: Contas anuais. Receitas orçamentárias realizadas (Anexo I-C) 2017 e Despesas orçamentárias empenhadas (Anexo I-D) 2017. In: Brasil. Secretaria do Tesouro Nacional, Siconfi: Sistema de Informações Contábeis e Fiscais do Setor Público Brasileiro. Brasília, DF, [2018]. Disponível em: https://siconfi.tesouro.gov.br/siconfi/pages/public/consulta_finbra/finbra_list.jsf. Acesso em: set. 2018</td></tr><tr><td>Rendimento mensal domiciliar per capita: IBGE, Diretoria de Pesquisas, Coordenação de Trabalho e Rendimento, Pesquisa Nacional por Amostra de Domicílios Contínua 2018</td></tr></table>'

# %%
dfibgeestados = pd.read_csv(nome_arquivo_ibge_estados, sep=',' , skiprows=1, nrows=27)
dfibgeestados.head()
# Out:
#      UF [-]  Código [-]  ... Total de veículos - veículos [2018] Unnamed: 14
# 0      Acre          12  ...                              277831         NaN
# 1   Alagoas          27  ...                              834827         NaN
# 2     Amapá          16  ...                              195039         NaN
# 3  Amazonas          13  ...                              883083         NaN
# 4     Bahia          29  ...                             4139107         NaN
#
# [5 rows x 15 columns]

# %%
dfibgeestados.tail()
# Out:
#             UF [-]  ...  Unnamed: 14
# 22         Roraima  ...          NaN
# 23  Santa Catarina  ...          NaN
# 24       São Paulo  ...          NaN
# 25         Sergipe  ...          NaN
# 26       Tocantins  ...          NaN
#
# [5 rows x 15 columns]

# %% [markdown]
# # Download dos dados da API de localidades do IBGE

# %%
import requests
url = 'https://servicodados.ibge.gov.br/api/v1/localidades/estados'
r = requests.get(url)
json_localidades = r.json()
print(json_localidades)
# Out:
# [{'id': 11, 'sigla': 'RO', 'nome': 'Rondônia', 'regiao': {'id': 1, 'sigla': 'N', 'nome': 'Norte'}}, {'id': 12, 'sigla': 'AC', 'nome': 'Acre', 'regiao': {'id': 1, 'sigla': 'N', 'nome': 'Norte'}}, {'id': 13, 'sigla': 'AM', 'nome': 'Amazonas', 'regiao': {'id': 1, 'sigla': 'N', 'nome': 'Norte'}}, {'id': 14, 'sigla': 'RR', 'nome': 'Roraima', 'regiao': {'id': 1, 'sigla': 'N', 'nome': 'Norte'}}, {'id': 15, 'sigla': 'PA', 'nome': 'Pará', 'regiao': {'id': 1, 'sigla': 'N', 'nome': 'Norte'}}, {'id': 16, 'sigla': 'AP', 'nome': 'Amapá', 'regiao': {'id': 1, 'sigla': 'N', 'nome': 'Norte'}}, {'id': 17, 'sigla': 'TO', 'nome': 'Tocantins', 'regiao': {'id': 1, 'sigla': 'N', 'nome': 'Norte'}}, {'id': 21, 'sigla': 'MA', 'nome': 'Maranhão', 'regiao': {'id': 2, 'sigla': 'NE', 'nome': 'Nordeste'}}, {'id': 22, 'sigla': 'PI', 'nome': 'Piauí', 'regiao': {'id': 2, 'sigla': 'NE', 'nome': 'Nordeste'}}, {'id': 23, 'sigla': 'CE', 'nome': 'Ceará', 'regiao': {'id': 2, 'sigla': 'NE', 'nome': 'Nordeste'}}, {'id': 24, 'sigla': 'RN', 'nome': 'Rio Grande do Norte', 'regiao': {'id': 2, 'sigla': 'NE', 'nome': 'Nordeste'}}, {'id': 25, 'sigla': 'PB', 'nome': 'Paraíba', 'regiao': {'id': 2, 'sigla': 'NE', 'nome': 'Nordeste'}}, {'id': 26, 'sigla': 'PE', 'nome': 'Pernambuco', 'regiao': {'id': 2, 'sigla': 'NE', 'nome': 'Nordeste'}}, {'id': 27, 'sigla': 'AL', 'nome': 'Alagoas', 'regiao': {'id': 2, 'sigla': 'NE', 'nome': 'Nordeste'}}, {'id': 28, 'sigla': 'SE', 'nome': 'Sergipe', 'regiao': {'id': 2, 'sigla': 'NE', 'nome': 'Nordeste'}}, {'id': 29, 'sigla': 'BA', 'nome': 'Bahia', 'regiao': {'id': 2, 'sigla': 'NE', 'nome': 'Nordeste'}}, {'id': 31, 'sigla': 'MG', 'nome': 'Minas Gerais', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}, {'id': 32, 'sigla': 'ES', 'nome': 'Espírito Santo', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}, {'id': 33, 'sigla': 'RJ', 'nome': 'Rio de Janeiro', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}, {'id': 35, 'sigla': 'SP', 'nome': 'São Paulo', 'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}, {'id': 41, 'sigla': 'PR', 'nome': 'Paraná', 'regiao': {'id': 4, 'sigla': 'S', 'nome': 'Sul'}}, {'id': 42, 'sigla': 'SC', 'nome': 'Santa Catarina', 'regiao': {'id': 4, 'sigla': 'S', 'nome': 'Sul'}}, {'id': 43, 'sigla': 'RS', 'nome': 'Rio Grande do Sul', 'regiao': {'id': 4, 'sigla': 'S', 'nome': 'Sul'}}, {'id': 50, 'sigla': 'MS', 'nome': 'Mato Grosso do Sul', 'regiao': {'id': 5, 'sigla': 'CO', 'nome': 'Centro-Oeste'}}, {'id': 51, 'sigla': 'MT', 'nome': 'Mato Grosso', 'regiao': {'id': 5, 'sigla': 'CO', 'nome': 'Centro-Oeste'}}, {'id': 52, 'sigla': 'GO', 'nome': 'Goiás', 'regiao': {'id': 5, 'sigla': 'CO', 'nome': 'Centro-Oeste'}}, {'id': 53, 'sigla': 'DF', 'nome': 'Distrito Federal', 'regiao': {'id': 5, 'sigla': 'CO', 'nome': 'Centro-Oeste'}}]

# %%
dflocalidades = pd.DataFrame(json_localidades)
dflocalidades.head()
# Out:
#    id sigla      nome                                    regiao
# 0  11    RO  Rondônia  {'id': 1, 'sigla': 'N', 'nome': 'Norte'}
# 1  12    AC      Acre  {'id': 1, 'sigla': 'N', 'nome': 'Norte'}
# 2  13    AM  Amazonas  {'id': 1, 'sigla': 'N', 'nome': 'Norte'}
# 3  14    RR   Roraima  {'id': 1, 'sigla': 'N', 'nome': 'Norte'}
# 4  15    PA      Pará  {'id': 1, 'sigla': 'N', 'nome': 'Norte'}

# %%
dflocalidades['regiao_sigla'] = dflocalidades['regiao'].map(lambda x : x['sigla'])
dflocalidades['regiao'] = dflocalidades['regiao'].map(lambda x : x['nome'])
dflocalidades.head()
# Out:
#    id sigla      nome regiao regiao_sigla
# 0  11    RO  Rondônia  Norte            N
# 1  12    AC      Acre  Norte            N
# 2  13    AM  Amazonas  Norte            N
# 3  14    RR   Roraima  Norte            N
# 4  15    PA      Pará  Norte            N

# %%
dflocalidades.columns = ['UF_CODIGO', 'UF_SIGLA', 'UF_NOME', 'REGIAO', 'REGIAO_SIGLA']
dflocalidades.head()
# Out:
#    UF_CODIGO UF_SIGLA   UF_NOME REGIAO REGIAO_SIGLA
# 0         11       RO  Rondônia  Norte            N
# 1         12       AC      Acre  Norte            N
# 2         13       AM  Amazonas  Norte            N
# 3         14       RR   Roraima  Norte            N
# 4         15       PA      Pará  Norte            N

# %% [markdown]
# # Download de página contendo a áea urbanizada das Unidades federativas

# %%
import pandas as pd
table_MN = pd.read_html('https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_%C3%A1rea', 
                        match='Unidades federativas do Brasil por área')
len(table_MN)

dfareaurbanizada = table_MN[0]
dfareaurbanizada.head()
# Out:
#   Unidade federativa Área urbanizada (km²)  ... País comparável  Referências
# 0               Acre                   495  ...        Suriname       [2][8]
# 1            Alagoas                  2021  ...           Haiti       [2][9]
# 2              Amapá                   693  ...          Grécia      [2][10]
# 3           Amazonas                  3951  ...        Mongólia      [2][11]
# 4              Bahia                  7629  ...          França      [2][12]
#
# [5 rows x 7 columns]

# %% [markdown]
# # Limpar os DataFrames deixando apenas os dados necessários

# %%
# %who DataFrame
# Out:
# dfareaurbanizada	 dfcovid	 dfibgeestados	 dflocalidades	 dfpib	 dfpopulacao	 dftransferencias

# %%
dfcovid.head()
# Out:
#    regiao estado  ... emAcompanhamentoNovos  interior/metropolitana
# 0  Brasil    NaN  ...                   NaN                     NaN
# 1  Brasil    NaN  ...                   NaN                     NaN
# 2  Brasil    NaN  ...                   NaN                     NaN
# 3  Brasil    NaN  ...                   NaN                     NaN
# 4  Brasil    NaN  ...                   NaN                     NaN
#
# [5 rows x 17 columns]

# %%
filtro = (dfcovid['estado'].isna() == False ) & ( dfcovid['codmun'].isna()  )
dfcovid = dfcovid[filtro][['regiao', 'estado', 'data' , 'casosNovos', 'obitosNovos']]

dfcovid['mes'] = dfcovid['data'].map(lambda x : x[:7])


print(dfcovid.shape)
dfcovid.head()
# Out:
# (8046, 6)
#     regiao estado        data  casosNovos  obitosNovos      mes
# 298  Norte     RO  2020-02-25           0            0  2020-02
# 299  Norte     RO  2020-02-26           0            0  2020-02
# 300  Norte     RO  2020-02-27           0            0  2020-02
# 301  Norte     RO  2020-02-28           0            0  2020-02
# 302  Norte     RO  2020-02-29           0            0  2020-02

# %%
dfregiaouf = dfcovid[['regiao', 'estado', 'mes',  'casosNovos', 'obitosNovos']]\
  .groupby(['regiao', 'estado', 'mes' ])  \
  .agg({'casosNovos':'sum', 'obitosNovos':'sum'})\
  .reset_index()
dfregiaouf.head()
# Out:
#          regiao estado      mes  casosNovos  obitosNovos
# 0  Centro-Oeste     DF  2020-02           0            0
# 1  Centro-Oeste     DF  2020-03         332            3
# 2  Centro-Oeste     DF  2020-04        1024           27
# 3  Centro-Oeste     DF  2020-05        8424          140
# 4  Centro-Oeste     DF  2020-06       39438          417

# %%
dfregiaouf.columns = ['REGIAO', 'UF_SIGLA', 'MÊS', 'QTD_CASOS', 'QTD_OBITOS']
dfregiaouf.head()
# Out:
#          REGIAO UF_SIGLA      MÊS  QTD_CASOS  QTD_OBITOS
# 0  Centro-Oeste       DF  2020-02          0           0
# 1  Centro-Oeste       DF  2020-03        332           3
# 2  Centro-Oeste       DF  2020-04       1024          27
# 3  Centro-Oeste       DF  2020-05       8424         140
# 4  Centro-Oeste       DF  2020-06      39438         417

# %%
del dfcovid

# %%
print( { k : v for k, v in dfregiaouf.dtypes.items()})
# Out:
# {'REGIAO': dtype('O'), 'UF_SIGLA': dtype('O'), 'MÊS': dtype('O'), 'QTD_CASOS': dtype('int64'), 'QTD_OBITOS': dtype('int64')}

# %%
tiposdict = {'REGIAO':'string' ,
             'UF_SIGLA': 'string' , 
             'MÊS': 'string' , 
             'QTD_CASOS': 'int64', 
             'QTD_OBITOS': 'int64'}

# %%
dfregiaouf = dfregiaouf.astype(tiposdict)
dfregiaouf.dtypes
# Out:
# REGIAO        string
# UF_SIGLA      string
# MÊS           string
# QTD_CASOS      int64
# QTD_OBITOS     int64
# dtype: object

# %%
dfregiaouf.head()
# Out:
#          REGIAO UF_SIGLA      MÊS  QTD_CASOS  QTD_OBITOS
# 0  Centro-Oeste       DF  2020-02          0           0
# 1  Centro-Oeste       DF  2020-03        332           3
# 2  Centro-Oeste       DF  2020-04       1024          27
# 3  Centro-Oeste       DF  2020-05       8424         140
# 4  Centro-Oeste       DF  2020-06      39438         417

# %% [markdown]
# #dfibgeestados

# %%
dfibgeestados.head()
# Out:
#      UF [-]  Código [-]  ... Total de veículos - veículos [2018] Unnamed: 14
# 0      Acre          12  ...                              277831         NaN
# 1   Alagoas          27  ...                              834827         NaN
# 2     Amapá          16  ...                              195039         NaN
# 3  Amazonas          13  ...                              883083         NaN
# 4     Bahia          29  ...                             4139107         NaN
#
# [5 rows x 15 columns]

# %%
coluna_selecionadas = ['UF [-]', 'Código [-]', 'Governador [2019]',
       'Área Territorial - km² [2019]',
       'IDH <span>Índice de desenvolvimento humano</span> [2010]',
       'Rendimento mensal domiciliar per capita - R$ [2019]']
dfibgeestados = dfibgeestados[coluna_selecionadas]
dfibgeestados.head()
# Out:
#      UF [-]  ...  Rendimento mensal domiciliar per capita - R$ [2019]
# 0      Acre  ...                                                890
# 1   Alagoas  ...                                                731
# 2     Amapá  ...                                                880
# 3  Amazonas  ...                                                842
# 4     Bahia  ...                                                913
#
# [5 rows x 6 columns]

# %%
colunas_renomeadas = {'UF [-]' : 'UF_NOME', 'Código [-]': 'UF_CODIGO', 'Governador [2019]':'GOVERNADOR',
       'Área Territorial - km² [2019]': 'AREA_TERRIT_KM2',
       'IDH <span>Índice de desenvolvimento humano</span> [2010]':'IDH',
       'Rendimento mensal domiciliar per capita - R$ [2019]': 'RENDA_MENS_PER_CAPITA'}
dfibgeestados = dfibgeestados.rename(colunas_renomeadas, axis='columns')
dfibgeestados.head()
# Out:
#     UF_NOME  UF_CODIGO  ...    IDH  RENDA_MENS_PER_CAPITA
# 0      Acre         12  ...  0.663                    890
# 1   Alagoas         27  ...  0.631                    731
# 2     Amapá         16  ...  0.708                    880
# 3  Amazonas         13  ...  0.674                    842
# 4     Bahia         29  ...  0.660                    913
#
# [5 rows x 6 columns]

# %%
dfibgeestados['GOVERNADOR'] = dfibgeestados['GOVERNADOR'].str.title()

dfibgeestados.head()
# Out:
#     UF_NOME  UF_CODIGO  ...    IDH  RENDA_MENS_PER_CAPITA
# 0      Acre         12  ...  0.663                    890
# 1   Alagoas         27  ...  0.631                    731
# 2     Amapá         16  ...  0.708                    880
# 3  Amazonas         13  ...  0.674                    842
# 4     Bahia         29  ...  0.660                    913
#
# [5 rows x 6 columns]

# %%
print( { k : v for k, v in dfibgeestados.dtypes.items()})
# Out:
# {'UF_NOME': dtype('O'), 'UF_CODIGO': dtype('int64'), 'GOVERNADOR': dtype('O'), 'AREA_TERRIT_KM2': dtype('float64'), 'IDH': dtype('float64'), 'RENDA_MENS_PER_CAPITA': dtype('int64')}

# %%
tiposdict =  {'UF_NOME': 'string', 
         'UF_CODIGO': 'int64',
         'GOVERNADOR': 'string', 
         'AREA_TERRIT_KM2': 'float64', 
         'IDH': 'float64', 
         'RENDA_MENS_PER_CAPITA': 'float64'}

# %%
dfibgeestados = dfibgeestados.astype(tiposdict)
dfibgeestados.dtypes
# Out:
# UF_NOME                   string
# UF_CODIGO                  int64
# GOVERNADOR                string
# AREA_TERRIT_KM2          float64
# IDH                      float64
# RENDA_MENS_PER_CAPITA    float64
# dtype: object

# %%
dfibgeestados.head()
# Out:
#     UF_NOME  UF_CODIGO  ...    IDH  RENDA_MENS_PER_CAPITA
# 0      Acre         12  ...  0.663                  890.0
# 1   Alagoas         27  ...  0.631                  731.0
# 2     Amapá         16  ...  0.708                  880.0
# 3  Amazonas         13  ...  0.674                  842.0
# 4     Bahia         29  ...  0.660                  913.0
#
# [5 rows x 6 columns]

# %% [markdown]
# # dfpib

# %%
dfpib.head()
# Out:
#   id_codigo_ibge   uf_nome      2002  ...       2015       2016       2017
# 0             11  Rondônia   7467630  ...   36563333   39460359   43516147
# 1             12      Acre   2971301  ...   13622802   13754240   14272941
# 2             13  Amazonas  22093338  ...   86568184   89039782   93240191
# 3             14   Roraima   2392033  ...   10242905   11013237   12104709
# 4             15      Pará  26482159  ...  130899505  138107514  155232404
#
# [5 rows x 18 columns]

# %%
dfpib = dfpib[['id_codigo_ibge', 'uf_nome', '2017']]
print(dfpib.shape)
dfpib.columns = ['UF_CODIGO', 'UF_NOME', 'PIB2017']
dfpib.head()
# Out:
# (27, 3)
#   UF_CODIGO   UF_NOME    PIB2017
# 0        11  Rondônia   43516147
# 1        12      Acre   14272941
# 2        13  Amazonas   93240191
# 3        14   Roraima   12104709
# 4        15      Pará  155232404

# %%
print( { k : v for k, v in dfpib.dtypes.items()})
# Out:
# {'UF_CODIGO': dtype('O'), 'UF_NOME': dtype('O'), 'PIB2017': dtype('O')}

# %%
tiposdict =  {'UF_NOME': 'string', 
         'UF_CODIGO': 'int64',
         'PIB2017': 'float64'}

# %%
dfpib = dfpib.astype(tiposdict)
dfpib.dtypes
# Out:
# UF_CODIGO      int64
# UF_NOME       string
# PIB2017      float64
# dtype: object

# %%
dfpib.head()
# Out:
#    UF_CODIGO   UF_NOME      PIB2017
# 0         11  Rondônia   43516147.0
# 1         12      Acre   14272941.0
# 2         13  Amazonas   93240191.0
# 3         14   Roraima   12104709.0
# 4         15      Pará  155232404.0

# %% [markdown]
# # dfpopulacao

# %%
dfpopulacao.head()
# Out:
#   id_codigo_ibge   uf_nome     2001  ...     2018     2019     2020
# 0             11  Rondônia  1407886  ...  1757589  1777225  1796460
# 1             12      Acre   574355  ...   869265   881935   894470
# 2             13  Amazonas  2900240  ...  4080611  4144597  4207714
# 3             14   Roraima   337237  ...   576568   605761   631181
# 4             15      Pará  6341736  ...  8513497  8602865  8690745
#
# [5 rows x 20 columns]

# %%
dfpopulacao = dfpopulacao[['id_codigo_ibge', 'uf_nome', '2020']]
print(dfpopulacao.shape)
dfpopulacao.columns = ['UF_CODIGO', 'UF_NOME', 'POPULACAO2020']
dfpopulacao.head()
# Out:
# (27, 3)
#   UF_CODIGO   UF_NOME POPULACAO2020
# 0        11  Rondônia       1796460
# 1        12      Acre        894470
# 2        13  Amazonas       4207714
# 3        14   Roraima        631181
# 4        15      Pará       8690745

# %%
print( { k : v for k, v in dfpopulacao.dtypes.items()})
# Out:
# {'UF_CODIGO': dtype('O'), 'UF_NOME': dtype('O'), 'POPULACAO2020': dtype('O')}

# %%
tiposdict =  {'UF_NOME': 'string', 
         'UF_CODIGO': 'int64',
         'POPULACAO2020': 'float64'}

# %%
dfpopulacao = dfpopulacao.astype(tiposdict)
dfpopulacao.dtypes
# Out:
# UF_CODIGO          int64
# UF_NOME           string
# POPULACAO2020    float64
# dtype: object

# %%
dfpopulacao.head()
# Out:
#    UF_CODIGO   UF_NOME  POPULACAO2020
# 0         11  Rondônia      1796460.0
# 1         12      Acre       894470.0
# 2         13  Amazonas      4207714.0
# 3         14   Roraima       631181.0
# 4         15      Pará      8690745.0

# %% [markdown]
# #dftransferencias

# %%
dftransferencias.tail(20)
# Out:
#      Regiao  UF   Ano          Transferência   Valor Consolidado
# 4565    Sul  SC  2019         Cessão Onerosa     R$92.042.737,18
# 4566    Sul  SC  2019      CIDE-Combustíveis     R$23.488.214,58
# 4567    Sul  SC  2019                    FPE    R$979.077.065,71
# 4568    Sul  SC  2019                 FUNDEB  R$2.565.117.362,78
# 4569    Sul  SC  2019                 FUNDEF              R$0,00
# 4570    Sul  SC  2019               IOF-Ouro          R$2.724,23
# 4571    Sul  SC  2019                IPI-Exp    R$247.531.127,62
# 4572    Sul  SC  2019  LC 87/96 (Lei Kandir)              R$0,00
# 4573    Sul  SC  2019              Royalties     R$25.645.331,32
# 4574    Sul  SC  2020                AFM/AFE     R$82.537.645,91
# 4575    Sul  SC  2020      CIDE-Combustíveis     R$19.373.098,19
# 4576    Sul  SC  2020                    FEX              R$0,00
# 4577    Sul  SC  2020                    FPE    R$909.116.235,10
# 4578    Sul  SC  2020                 FUNDEB  R$2.307.909.418,68
# 4579    Sul  SC  2020                 FUNDEF              R$0,00
# 4580    Sul  SC  2020               IOF-Ouro              R$0,00
# 4581    Sul  SC  2020                IPI-Exp    R$255.945.687,94
# 4582    Sul  SC  2020     LC 173/2020 (PFEC)  R$1.359.137.456,85
# 4583    Sul  SC  2020  LC 87/96 (Lei Kandir)              R$0,00
# 4584    Sul  SC  2020              Royalties     R$20.651.698,99

# %%
dftransferencias = dftransferencias[(dftransferencias.Ano == 2020) & \
                                    (dftransferencias['Transferência'] == 'LC 173/2020 (PFEC)')]\
                                    [['UF','Valor Consolidado']]
dftransferencias.head()
# Out:
#      UF   Valor Consolidado
# 151  DF    R$704.123.564,16
# 323  GO  R$1.332.470.209,00
# 485  MS    R$722.599.528,06
# 664  MT  R$1.485.643.967,09
# 826  AL    R$577.671.925,99

# %%
dftransferencias.columns = ['UF_SIGLA','VALOR_TRANSFERENCIAS']
dftransferencias['VALOR_TRANSFERENCIAS'] = dftransferencias['VALOR_TRANSFERENCIAS'].\
      map(lambda x : float(x.replace('R$','').replace('.','').replace(',','.')))
dftransferencias.head()
# Out:
#     UF_SIGLA  VALOR_TRANSFERENCIAS
# 151       DF          7.041236e+08
# 323       GO          1.332470e+09
# 485       MS          7.225995e+08
# 664       MT          1.485644e+09
# 826       AL          5.776719e+08

# %%
print( { k : v for k, v in dftransferencias.dtypes.items()})
# Out:
# {'UF_SIGLA': dtype('O'), 'VALOR_TRANSFERENCIAS': dtype('float64')}

# %%
tiposdict =  {'UF_SIGLA': 'string', 
         'VALOR_TRANSFERENCIAS': 'float64'}

# %%
dftransferencias = dftransferencias.astype(tiposdict)
dftransferencias.dtypes
# Out:
# UF_SIGLA                 string
# VALOR_TRANSFERENCIAS    float64
# dtype: object

# %%
dftransferencias.head()
# Out:
#     UF_SIGLA  VALOR_TRANSFERENCIAS
# 151       DF          7.041236e+08
# 323       GO          1.332470e+09
# 485       MS          7.225995e+08
# 664       MT          1.485644e+09
# 826       AL          5.776719e+08

# %% [markdown]
# # dflocalidades

# %%
dflocalidades.head()
# Out:
#    UF_CODIGO UF_SIGLA   UF_NOME REGIAO REGIAO_SIGLA
# 0         11       RO  Rondônia  Norte            N
# 1         12       AC      Acre  Norte            N
# 2         13       AM  Amazonas  Norte            N
# 3         14       RR   Roraima  Norte            N
# 4         15       PA      Pará  Norte            N

# %%
print( { k : v for k, v in dflocalidades.dtypes.items()})
# Out:
# {'UF_CODIGO': dtype('int64'), 'UF_SIGLA': dtype('O'), 'UF_NOME': dtype('O'), 'REGIAO': dtype('O'), 'REGIAO_SIGLA': dtype('O')}

# %%
tiposdict = {'UF_CODIGO': 'int64', 
          'UF_SIGLA': 'string', 
          'UF_NOME': 'string', 
          'REGIAO': 'string', 
          'REGIAO_SIGLA': 'string'}

# %%
dflocalidades = dflocalidades.astype(tiposdict)
dflocalidades.dtypes
# Out:
# UF_CODIGO        int64
# UF_SIGLA        string
# UF_NOME         string
# REGIAO          string
# REGIAO_SIGLA    string
# dtype: object

# %%
dflocalidades.head()
# Out:
#    UF_CODIGO UF_SIGLA   UF_NOME REGIAO REGIAO_SIGLA
# 0         11       RO  Rondônia  Norte            N
# 1         12       AC      Acre  Norte            N
# 2         13       AM  Amazonas  Norte            N
# 3         14       RR   Roraima  Norte            N
# 4         15       PA      Pará  Norte            N

# %% [markdown]
# # DataFrame de áreas urbanizadas

# %%
dfareaurbanizada.head()
# Out:
#   Unidade federativa Área urbanizada (km²)  ... País comparável  Referências
# 0               Acre                   495  ...        Suriname       [2][8]
# 1            Alagoas                  2021  ...           Haiti       [2][9]
# 2              Amapá                   693  ...          Grécia      [2][10]
# 3           Amazonas                  3951  ...        Mongólia      [2][11]
# 4              Bahia                  7629  ...          França      [2][12]
#
# [5 rows x 7 columns]

# %%
dfareaurbanizada = dfareaurbanizada [['Unidade federativa', 'Área urbanizada (km²)']]
dfareaurbanizada.head()
# Out:
#   Unidade federativa Área urbanizada (km²)
# 0               Acre                   495
# 1            Alagoas                  2021
# 2              Amapá                   693
# 3           Amazonas                  3951
# 4              Bahia                  7629

# %%
dfareaurbanizada.columns  = ['UF_NOME', 'AREA_URBANIZADA']
dfareaurbanizada.tail()
# Out:
#            UF_NOME AREA_URBANIZADA
# 22         Roraima             406
# 23  Santa Catarina            8782
# 24       São Paulo           4 971
# 25         Sergipe            1187
# 26       Tocantins             996

# %%
dfareaurbanizada[:]['AREA_URBANIZADA']=  dfareaurbanizada['AREA_URBANIZADA'].str.replace('\xa0','')
dfareaurbanizada[:]['AREA_URBANIZADA']=  dfareaurbanizada['AREA_URBANIZADA'].str.replace('.','')
dfareaurbanizada[:]['AREA_URBANIZADA']=  dfareaurbanizada['AREA_URBANIZADA'].str.replace(',','.')

# %%
dfareaurbanizada.head()
# Out:
#     UF_NOME AREA_URBANIZADA
# 0      Acre             495
# 1   Alagoas            2021
# 2     Amapá             693
# 3  Amazonas            3951
# 4     Bahia            7629

# %%
print( { k : v for k, v in dfareaurbanizada.dtypes.items()})
# Out:
# {'UF_NOME': dtype('O'), 'AREA_URBANIZADA': dtype('O')}

# %%
tiposdict = {'UF_NOME': 'string', 
          'AREA_URBANIZADA': 'float64'}

# %%
dfareaurbanizada = dfareaurbanizada.astype(tiposdict)
dfareaurbanizada.dtypes
# Out:
# UF_NOME             string
# AREA_URBANIZADA    float64
# dtype: object

# %%
dfareaurbanizada.head()
# Out:
#     UF_NOME  AREA_URBANIZADA
# 0      Acre            495.0
# 1   Alagoas           2021.0
# 2     Amapá            693.0
# 3  Amazonas           3951.0
# 4     Bahia           7629.0

# %% [markdown]
# # Integrar todos os dados no mesmo DataFrame

# %%
# %who DataFrame
# Out:
# dfareaurbanizada	 dfibgeestados	 dflocalidades	 dfpib	 dfpopulacao	 dfregiaouf	 dftransferencias

# %%
dfregiaouf.head()
# Out:
#          REGIAO UF_SIGLA      MÊS  QTD_CASOS  QTD_OBITOS
# 0  Centro-Oeste       DF  2020-02          0           0
# 1  Centro-Oeste       DF  2020-03        332           3
# 2  Centro-Oeste       DF  2020-04       1024          27
# 3  Centro-Oeste       DF  2020-05       8424         140
# 4  Centro-Oeste       DF  2020-06      39438         417

# %% [markdown]
# # Totalizar os casos por estado e integrar com o demais dataframes

# %%
dfregiaouf.columns
# Out:
# Index(['REGIAO', 'UF_SIGLA', 'MÊS', 'QTD_CASOS', 'QTD_OBITOS'], dtype='object')

# %%
dfcovidtotalestados = dfregiaouf[['UF_SIGLA', 'QTD_CASOS', 'QTD_OBITOS']].groupby('UF_SIGLA').sum()
dfcovidtotalestados.head()
# Out:
#           QTD_CASOS  QTD_OBITOS
# UF_SIGLA
# AC            39341         757
# AL           100619        2399
# AM           190968        5062
# AP            64549         864
# BA           464083        8748

# %%
dfcovidtotalestados.sum()
# Out:
# QTD_CASOS     7162978
# QTD_OBITOS     185650
# dtype: int64

# %%
dflocalidades.dtypes
# Out:
# UF_CODIGO        int64
# UF_SIGLA        string
# UF_NOME         string
# REGIAO          string
# REGIAO_SIGLA    string
# dtype: object

# %%
dfcovidtotalestados.index
# Out:
# Index(['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG', 'MS',
#        'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR', 'RS', 'SC',
#        'SE', 'SP', 'TO'],
#       dtype='object', name='UF_SIGLA')

# %%
dfcompleto =  dfcovidtotalestados.merge(dflocalidades, on='UF_SIGLA')
dfcompleto.head()
# Out:
#   UF_SIGLA  QTD_CASOS  QTD_OBITOS  UF_CODIGO   UF_NOME    REGIAO REGIAO_SIGLA
# 0       AC      39341         757         12      Acre     Norte            N
# 1       AL     100619        2399         27   Alagoas  Nordeste           NE
# 2       AM     190968        5062         13  Amazonas     Norte            N
# 3       AP      64549         864         16     Amapá     Norte            N
# 4       BA     464083        8748         29     Bahia  Nordeste           NE

# %%
dfcompleto['UF_SIGLA'] = dfcompleto['UF_SIGLA'].astype('string')
dfcompleto.dtypes
# Out:
# UF_SIGLA        string
# QTD_CASOS        int64
# QTD_OBITOS       int64
# UF_CODIGO        int64
# UF_NOME         string
# REGIAO          string
# REGIAO_SIGLA    string
# dtype: object

# %%
dfibgeestados.head()
# Out:
#     UF_NOME  UF_CODIGO  ...    IDH  RENDA_MENS_PER_CAPITA
# 0      Acre         12  ...  0.663                  890.0
# 1   Alagoas         27  ...  0.631                  731.0
# 2     Amapá         16  ...  0.708                  880.0
# 3  Amazonas         13  ...  0.674                  842.0
# 4     Bahia         29  ...  0.660                  913.0
#
# [5 rows x 6 columns]

# %%
dfcompleto =  dfcompleto.merge(dfibgeestados[['UF_NOME', 'GOVERNADOR', 'AREA_TERRIT_KM2', 'IDH','RENDA_MENS_PER_CAPITA']], 
                  on=['UF_NOME'], validate='one_to_one')
dfcompleto.head()
# Out:
#   UF_SIGLA  QTD_CASOS  ...    IDH  RENDA_MENS_PER_CAPITA
# 0       AC      39341  ...  0.663                  890.0
# 1       AL     100619  ...  0.631                  731.0
# 2       AM     190968  ...  0.674                  842.0
# 3       AP      64549  ...  0.708                  880.0
# 4       BA     464083  ...  0.660                  913.0
#
# [5 rows x 11 columns]

# %%
dfcompleto.dtypes
# Out:
# UF_SIGLA                  string
# QTD_CASOS                  int64
# QTD_OBITOS                 int64
# UF_CODIGO                  int64
# UF_NOME                   string
# REGIAO                    string
# REGIAO_SIGLA              string
# GOVERNADOR                string
# AREA_TERRIT_KM2          float64
# IDH                      float64
# RENDA_MENS_PER_CAPITA    float64
# dtype: object

# %%
dfpib.head()
# Out:
#    UF_CODIGO   UF_NOME      PIB2017
# 0         11  Rondônia   43516147.0
# 1         12      Acre   14272941.0
# 2         13  Amazonas   93240191.0
# 3         14   Roraima   12104709.0
# 4         15      Pará  155232404.0

# %%
dfcompleto =  dfcompleto.merge(dfpib[['UF_CODIGO','PIB2017']], on='UF_CODIGO', validate='one_to_one')
dfcompleto.head()
# Out:
#   UF_SIGLA  QTD_CASOS  QTD_OBITOS  ...    IDH RENDA_MENS_PER_CAPITA      PIB2017
# 0       AC      39341         757  ...  0.663                 890.0   14272941.0
# 1       AL     100619        2399  ...  0.631                 731.0   52851067.0
# 2       AM     190968        5062  ...  0.674                 842.0   93240191.0
# 3       AP      64549         864  ...  0.708                 880.0   15481908.0
# 4       BA     464083        8748  ...  0.660                 913.0  268724090.0
#
# [5 rows x 12 columns]

# %%
dfcompleto.dtypes
# Out:
# UF_SIGLA                  string
# QTD_CASOS                  int64
# QTD_OBITOS                 int64
# UF_CODIGO                  int64
# UF_NOME                   string
# REGIAO                    string
# REGIAO_SIGLA              string
# GOVERNADOR                string
# AREA_TERRIT_KM2          float64
# IDH                      float64
# RENDA_MENS_PER_CAPITA    float64
# PIB2017                  float64
# dtype: object

# %%
dfpopulacao.head()
# Out:
#    UF_CODIGO   UF_NOME  POPULACAO2020
# 0         11  Rondônia      1796460.0
# 1         12      Acre       894470.0
# 2         13  Amazonas      4207714.0
# 3         14   Roraima       631181.0
# 4         15      Pará      8690745.0

# %%
dfcompleto =  dfcompleto.merge(dfpopulacao[['UF_CODIGO','POPULACAO2020']], on='UF_CODIGO', validate='one_to_one')
dfcompleto.head()
# Out:
#   UF_SIGLA  QTD_CASOS  ...      PIB2017  POPULACAO2020
# 0       AC      39341  ...   14272941.0       894470.0
# 1       AL     100619  ...   52851067.0      3351543.0
# 2       AM     190968  ...   93240191.0      4207714.0
# 3       AP      64549  ...   15481908.0       861773.0
# 4       BA     464083  ...  268724090.0     14930634.0
#
# [5 rows x 13 columns]

# %%
dfcompleto.dtypes
# Out:
# UF_SIGLA                  string
# QTD_CASOS                  int64
# QTD_OBITOS                 int64
# UF_CODIGO                  int64
# UF_NOME                   string
# REGIAO                    string
# REGIAO_SIGLA              string
# GOVERNADOR                string
# AREA_TERRIT_KM2          float64
# IDH                      float64
# RENDA_MENS_PER_CAPITA    float64
# PIB2017                  float64
# POPULACAO2020            float64
# dtype: object

# %%
dftransferencias.head()
# Out:
#     UF_SIGLA  VALOR_TRANSFERENCIAS
# 151       DF          7.041236e+08
# 323       GO          1.332470e+09
# 485       MS          7.225995e+08
# 664       MT          1.485644e+09
# 826       AL          5.776719e+08

# %%
dfcompleto =  dfcompleto.merge(dftransferencias, on='UF_SIGLA', validate='one_to_one')
dfcompleto.head()
# Out:
#   UF_SIGLA  QTD_CASOS  ...  POPULACAO2020  VALOR_TRANSFERENCIAS
# 0       AC      39341  ...       894470.0          3.711812e+08
# 1       AL     100619  ...      3351543.0          5.776719e+08
# 2       AM     190968  ...      4207714.0          8.938841e+08
# 3       AP      64549  ...       861773.0          4.546551e+08
# 4       BA     464083  ...     14930634.0          2.022776e+09
#
# [5 rows x 14 columns]

# %%
dfareaurbanizada.head()
# Out:
#     UF_NOME  AREA_URBANIZADA
# 0      Acre            495.0
# 1   Alagoas           2021.0
# 2     Amapá            693.0
# 3  Amazonas           3951.0
# 4     Bahia           7629.0

# %%
dfcompleto =  dfcompleto.merge(dfareaurbanizada, on='UF_NOME', validate='one_to_one')
dfcompleto.head()
# Out:
#   UF_SIGLA  QTD_CASOS  ...  VALOR_TRANSFERENCIAS  AREA_URBANIZADA
# 0       AC      39341  ...          3.711812e+08            495.0
# 1       AL     100619  ...          5.776719e+08           2021.0
# 2       AM     190968  ...          8.938841e+08           3951.0
# 3       AP      64549  ...          4.546551e+08            693.0
# 4       BA     464083  ...          2.022776e+09           7629.0
#
# [5 rows x 15 columns]

# %%
dfcompleto.dtypes
# Out:
# UF_SIGLA                  string
# QTD_CASOS                  int64
# QTD_OBITOS                 int64
# UF_CODIGO                  int64
# UF_NOME                   string
# REGIAO                    string
# REGIAO_SIGLA              string
# GOVERNADOR                string
# AREA_TERRIT_KM2          float64
# IDH                      float64
# RENDA_MENS_PER_CAPITA    float64
# PIB2017                  float64
# POPULACAO2020            float64
# VALOR_TRANSFERENCIAS     float64
# AREA_URBANIZADA          float64
# dtype: object

# %%
dfcompleto.head()
# Out:
#   UF_SIGLA  QTD_CASOS  ...  VALOR_TRANSFERENCIAS  AREA_URBANIZADA
# 0       AC      39341  ...          3.711812e+08            495.0
# 1       AL     100619  ...          5.776719e+08           2021.0
# 2       AM     190968  ...          8.938841e+08           3951.0
# 3       AP      64549  ...          4.546551e+08            693.0
# 4       BA     464083  ...          2.022776e+09           7629.0
#
# [5 rows x 15 columns]

# %%
dfcompleto = dfcompleto[['UF_CODIGO','UF_SIGLA',  'UF_NOME', 'REGIAO',
       'REGIAO_SIGLA', 'GOVERNADOR', 'AREA_TERRIT_KM2', 'IDH',
       'RENDA_MENS_PER_CAPITA', 'PIB2017', 'POPULACAO2020', 'AREA_URBANIZADA',
       'VALOR_TRANSFERENCIAS', 'QTD_CASOS', 'QTD_OBITOS']]
dfcompleto.head()
# Out:
#    UF_CODIGO UF_SIGLA   UF_NOME  ... VALOR_TRANSFERENCIAS QTD_CASOS QTD_OBITOS
# 0         12       AC      Acre  ...         3.711812e+08     39341        757
# 1         27       AL   Alagoas  ...         5.776719e+08    100619       2399
# 2         13       AM  Amazonas  ...         8.938841e+08    190968       5062
# 3         16       AP     Amapá  ...         4.546551e+08     64549        864
# 4         29       BA     Bahia  ...         2.022776e+09    464083       8748
#
# [5 rows x 15 columns]

# %%
dfcompleto = dfcompleto.sort_values(['REGIAO','UF_SIGLA'])
dfcompleto = dfcompleto.set_index(['REGIAO','UF_SIGLA'])
dfcompleto.head()
# Out:
#                        UF_CODIGO             UF_NOME  ... QTD_CASOS QTD_OBITOS
# REGIAO       UF_SIGLA                                 ...
# Centro-Oeste DF               53    Distrito Federal  ...    243212       4132
#              GO               52               Goiás  ...    299682       6651
#              MS               50  Mato Grosso do Sul  ...    119079       2009
#              MT               51         Mato Grosso  ...    170594       4257
# Nordeste     AL               27             Alagoas  ...    100619       2399
#
# [5 rows x 13 columns]

# %% [markdown]
# # Gerar DataFrame Agregado por Regiao

# %%
{ x : 'sum' for x in dfcompleto.columns}
# Out:
# {'AREA_TERRIT_KM2': 'sum',
#  'AREA_URBANIZADA': 'sum',
#  'GOVERNADOR': 'sum',
#  'IDH': 'sum',
#  'PIB2017': 'sum',
#  'POPULACAO2020': 'sum',
#  'QTD_CASOS': 'sum',
#  'QTD_OBITOS': 'sum',
#  'REGIAO_SIGLA': 'sum',
#  'RENDA_MENS_PER_CAPITA': 'sum',
#  'UF_CODIGO': 'sum',
#  'UF_NOME': 'sum',
#  'VALOR_TRANSFERENCIAS': 'sum'}

# %%
metricasregionais = {'AREA_TERRIT_KM2': 'sum',
 'IDH': 'mean',
 'PIB2017': 'sum',
 'POPULACAO2020': 'sum',
 'QTD_CASOS': 'sum',
 'QTD_OBITOS': 'sum',
 'RENDA_MENS_PER_CAPITA': 'mean',
 'VALOR_TRANSFERENCIAS': 'sum',
 'AREA_URBANIZADA': 'sum',
 'UF_NOME':'count'}

# %%
 dfcompletoregiao =  dfcompleto.reset_index()[['UF_NOME', 'REGIAO','AREA_TERRIT_KM2', 'IDH',
                    'RENDA_MENS_PER_CAPITA', 'PIB2017', 'POPULACAO2020','AREA_URBANIZADA',
                    'VALOR_TRANSFERENCIAS', 'QTD_CASOS', 'QTD_OBITOS', ]]\
                    .groupby('REGIAO')\
                    .agg(metricasregionais)\
                    .rename({'UF_NOME':'QTD_UFS'},  axis='columns')\
                    .sort_values('QTD_OBITOS', ascending=False)
dfcompletoregiao.head()
# Out:
#               AREA_TERRIT_KM2       IDH  ...  AREA_URBANIZADA  QTD_UFS
# REGIAO                                   ...
# Sudeste            924565.478  0.753750  ...          13252.7        4
# Nordeste          1552167.009  0.659778  ...          35558.0        9
# Sul                576736.819  0.756333  ...          12032.7        3
# Norte             3850509.943  0.683857  ...          16108.0        7
# Centro-Oeste      1606316.665  0.753250  ...          16935.6        4
#
# [5 rows x 10 columns]

# %%
metricasbrasil= {'AREA_TERRIT_KM2': 'sum',
 'IDH': 'mean',
 'PIB2017': 'sum',
 'POPULACAO2020': 'sum',
 'QTD_CASOS': 'sum',
 'QTD_OBITOS': 'sum',
 'RENDA_MENS_PER_CAPITA': 'mean',
 'VALOR_TRANSFERENCIAS': 'sum',
 'AREA_URBANIZADA': 'sum',
 'QTD_UFS':'sum'}

# %%
dfcompletoBrasil = pd.DataFrame(dfcompletoregiao.agg(metricasbrasil)).T
dfcompletoBrasil.head()
# Out:
#    AREA_TERRIT_KM2       IDH  ...  AREA_URBANIZADA  QTD_UFS
# 0      8510295.914  0.721394  ...          93887.0     27.0
#
# [1 rows x 10 columns]

# %% [markdown]
# ## Calcula a proporção do estado em relação a sua regiao

# %%
dfcomplentocompregiao = dfcompleto[['AREA_TERRIT_KM2', 'IDH', 'PIB2017', 'POPULACAO2020','AREA_URBANIZADA', 'QTD_CASOS',
                                     'QTD_OBITOS', 'RENDA_MENS_PER_CAPITA', 'VALOR_TRANSFERENCIAS']]\
                                      / dfcompletoregiao[['AREA_TERRIT_KM2', 'IDH', 'PIB2017', 'POPULACAO2020','AREA_URBANIZADA', 'QTD_CASOS',
                                     'QTD_OBITOS', 'RENDA_MENS_PER_CAPITA', 'VALOR_TRANSFERENCIAS']]\
                                      * 100.00
dfcomplentocompregiao.head()
# Out:
#                        AREA_TERRIT_KM2  ...  VALOR_TRANSFERENCIAS
# REGIAO       UF_SIGLA                   ...
# Centro-Oeste DF               0.358633  ...             16.587763
#              GO              21.179095  ...             31.390372
#              MS              22.233819  ...             17.023021
#              MT              56.228453  ...             34.998844
# Nordeste     AL               1.793834  ...              6.880064
#
# [5 rows x 9 columns]

# %%
dfcomplentocompregiao.groupby('REGIAO').sum()
# Out:
#               AREA_TERRIT_KM2  ...  VALOR_TRANSFERENCIAS
# REGIAO                         ...
# Centro-Oeste            100.0  ...                 100.0
# Nordeste                100.0  ...                 100.0
# Norte                   100.0  ...                 100.0
# Sudeste                 100.0  ...                 100.0
# Sul                     100.0  ...                 100.0
#
# [5 rows x 9 columns]

# %% [markdown]
# # Calcula a Proporção dos estado em relação ao Brasil

# %%
dfcompleto.head()
# Out:
#                        UF_CODIGO             UF_NOME  ... QTD_CASOS QTD_OBITOS
# REGIAO       UF_SIGLA                                 ...
# Centro-Oeste DF               53    Distrito Federal  ...    243212       4132
#              GO               52               Goiás  ...    299682       6651
#              MS               50  Mato Grosso do Sul  ...    119079       2009
#              MT               51         Mato Grosso  ...    170594       4257
# Nordeste     AL               27             Alagoas  ...    100619       2399
#
# [5 rows x 13 columns]

# %%
metricasbrasil= {'AREA_TERRIT_KM2': 'sum',
 'IDH': 'mean',
 'PIB2017': 'sum',
 'POPULACAO2020': 'sum',
 'QTD_CASOS': 'sum',
 'QTD_OBITOS': 'sum',
 'RENDA_MENS_PER_CAPITA': 'mean',
 'VALOR_TRANSFERENCIAS': 'sum',
 'AREA_URBANIZADA': 'sum'}

# %%
 dfcompleto.agg(metricasbrasil)[['AREA_TERRIT_KM2', 'IDH', 'PIB2017', 'POPULACAO2020','AREA_URBANIZADA', 'QTD_CASOS',
                                     'QTD_OBITOS', 'RENDA_MENS_PER_CAPITA', 'VALOR_TRANSFERENCIAS']]
# Out:
# AREA_TERRIT_KM2          8.510296e+06
# IDH                      7.045185e-01
# PIB2017                  6.585479e+09
# POPULACAO2020            2.117557e+08
# AREA_URBANIZADA          9.388700e+04
# QTD_CASOS                7.162978e+06
# QTD_OBITOS               1.856500e+05
# RENDA_MENS_PER_CAPITA    1.238704e+03
# VALOR_TRANSFERENCIAS     3.700000e+10
# dtype: float64

# %%
dfcomplentocompbrasil = dfcompleto[['AREA_TERRIT_KM2', 'IDH', 'PIB2017', 'POPULACAO2020','AREA_URBANIZADA', 'QTD_CASOS',
                                     'QTD_OBITOS', 'RENDA_MENS_PER_CAPITA', 'VALOR_TRANSFERENCIAS']]\
                        / dfcompleto.agg(metricasbrasil)[['AREA_TERRIT_KM2', 'IDH', 'PIB2017', 'POPULACAO2020','AREA_URBANIZADA', 'QTD_CASOS',
                                     'QTD_OBITOS', 'RENDA_MENS_PER_CAPITA', 'VALOR_TRANSFERENCIAS']]\
                        * 100.00
dfcomplentocompbrasil.head()
# Out:
#                        AREA_TERRIT_KM2  ...  VALOR_TRANSFERENCIAS
# REGIAO       UF_SIGLA                   ...
# Centro-Oeste DF               0.067692  ...              1.903037
#              GO               3.997550  ...              3.601271
#              MS               4.196629  ...              1.952972
#              MT              10.613109  ...              4.015254
# Nordeste     AL               0.327172  ...              1.561275
#
# [5 rows x 9 columns]

# %%
dfcomplentocompbrasil.sum()
# Out:
# AREA_TERRIT_KM2           100.0
# IDH                      2700.0
# PIB2017                   100.0
# POPULACAO2020             100.0
# AREA_URBANIZADA           100.0
# QTD_CASOS                 100.0
# QTD_OBITOS                100.0
# RENDA_MENS_PER_CAPITA    2700.0
# VALOR_TRANSFERENCIAS      100.0
# dtype: float64

# %% [markdown]
# ## Visualização dos dados

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [6, 4]
plt.rcParams["figure.dpi"] = 100
plt.rcParams["figure.facecolor"] = 'MediumSeaGreen'

# %%
dfcompletoregiao.head()
# Out:
#               AREA_TERRIT_KM2       IDH  ...  AREA_URBANIZADA  QTD_UFS
# REGIAO                                   ...
# Sudeste            924565.478  0.753750  ...          13252.7        4
# Nordeste          1552167.009  0.659778  ...          35558.0        9
# Sul                576736.819  0.756333  ...          12032.7        3
# Norte             3850509.943  0.683857  ...          16108.0        7
# Centro-Oeste      1606316.665  0.753250  ...          16935.6        4
#
# [5 rows x 10 columns]

# %%
dfcompletoregiao.sort_values('AREA_TERRIT_KM2', ascending=False)['AREA_TERRIT_KM2']
# Out:
# REGIAO
# Norte           3850509.943
# Centro-Oeste    1606316.665
# Nordeste        1552167.009
# Sudeste          924565.478
# Sul              576736.819
# Name: AREA_TERRIT_KM2, dtype: float64

# %%
dfcompletoregiao.sort_values('AREA_TERRIT_KM2', ascending=False)['AREA_TERRIT_KM2'].plot(kind='bar', figsize=(4, 4));

# %%
dfcompletoregiao.sort_values('AREA_TERRIT_KM2', ascending=False)['AREA_TERRIT_KM2'].plot(kind='pie', figsize=(4, 4));

# %%
dfcompletoregiao.sort_values('AREA_TERRIT_KM2', ascending=False)['AREA_TERRIT_KM2'].plot.bar(figsize=(4, 4))

# %%
ax = dfcompletoregiao.sort_values('AREA_TERRIT_KM2', ascending=False)['AREA_TERRIT_KM2'].plot.pie(figsize=(4, 4))

# %%
import numpy as np
plt.rcParams["figure.figsize"] = [20, 20]
axes = dfcompletoregiao[['AREA_TERRIT_KM2', 'PIB2017', 'POPULACAO2020', 'QTD_CASOS',
       'QTD_OBITOS',  'VALOR_TRANSFERENCIAS',
       'AREA_URBANIZADA', 'QTD_UFS']].plot.pie(subplots=True, layout=(2, 4), autopct='%.2f',
                                               figsize=(12, 6), sharex=True, rot=45, legend=False,
                                               )

axes[0,1].legend(loc=1)
for ax in axes[0, :]:
  ax.yaxis.label.set_visible(False)
plt.subplots_adjust( wspace = 0.4, hspace = 0.4)

# %%
fig = plt.figure()
axes = dfcompletoregiao[['AREA_TERRIT_KM2', 'PIB2017', 'POPULACAO2020', 'QTD_CASOS',
       'QTD_OBITOS',  'VALOR_TRANSFERENCIAS',
       'AREA_URBANIZADA', 'QTD_UFS']].plot.bar(subplots=True, layout=(2, 4), 
                                               figsize=(12, 6), sharex=True, rot=90, legend=False)
plt.subplots_adjust( wspace = 0.4, hspace = 0.3)
plt.suptitle("Comparativos das Regiões do Brasil")
plt.show()

# %%
dfcompleto.head()
# Out:
#                        UF_CODIGO             UF_NOME  ... QTD_CASOS QTD_OBITOS
# REGIAO       UF_SIGLA                                 ...
# Centro-Oeste DF               53    Distrito Federal  ...    243212       4132
#              GO               52               Goiás  ...    299682       6651
#              MS               50  Mato Grosso do Sul  ...    119079       2009
#              MT               51         Mato Grosso  ...    170594       4257
# Nordeste     AL               27             Alagoas  ...    100619       2399
#
# [5 rows x 13 columns]

# %%
dfcompleto['OBITOS_100MIL'] = dfcompleto['QTD_OBITOS'] / (dfcompleto['POPULACAO2020'] / 100_000)

# %%
ax = dfcompleto.plot.scatter(x='IDH', y='OBITOS_100MIL', figsize=(8, 4) , s=dfcompleto['POPULACAO2020']//100_000,
                      colormap='viridis')

# %%
from pandas.plotting import scatter_matrix
axes = scatter_matrix(dfcompleto[['IDH', 'PIB2017', 'POPULACAO2020', 'QTD_CASOS',
       'QTD_OBITOS',  'VALOR_TRANSFERENCIAS']], figsize=(8, 8), diagonal='hist')

# %%
dfregiaouf.head()
# Out:
#          REGIAO UF_SIGLA      MÊS  QTD_CASOS  QTD_OBITOS
# 0  Centro-Oeste       DF  2020-02          0           0
# 1  Centro-Oeste       DF  2020-03        332           3
# 2  Centro-Oeste       DF  2020-04       1024          27
# 3  Centro-Oeste       DF  2020-05       8424         140
# 4  Centro-Oeste       DF  2020-06      39438         417

# %%
import matplotlib.pyplot as plt
import string
import seaborn as sns
plt.rc('figure', figsize = (8, 6))
dfresumo = dfregiaouf[['UF_SIGLA','QTD_CASOS', 'QTD_OBITOS']].groupby('UF_SIGLA').sum()
l = dfresumo.index


fig , (ax1, ax2) = plt.subplots(2, 1)

sns.scatterplot(x=np.log(dfresumo['QTD_CASOS']),
                y=np.log(dfresumo['QTD_OBITOS']), ax=ax1)
ax1.set_title('Casos X Obitos por COVID-19 no Brasil (Em milhares)')
#ax1.set_xlabel('Região')
ax1.set_ylabel('Log(Quant. Óbitos)')
#ax1.set_xlabel('Log(Quant. Casos)')

for l1, x1, y1 in zip(l, x, y):
  ax1.annotate(l1, xy=(x1,y1),
               xytext=(5,-5),
               textcoords='offset points')
  
sns.regplot(x=x, y=y, ax=ax2)
ax2.set_ylabel('Log(Quant. Óbitos)')
ax2.set_xlabel('Log(Quant. Casos)')

for l1, x1, y1 in zip(l, x, y):
  ax2.annotate(l1, xy=(x1,y1),
               xytext=(5,-5),
               textcoords='offset points')
plt.show()

# %%
dfregiaouf.head()
# Out:
#          REGIAO UF_SIGLA      MÊS  QTD_CASOS  QTD_OBITOS
# 0  Centro-Oeste       DF  2020-02          0           0
# 1  Centro-Oeste       DF  2020-03        332           3
# 2  Centro-Oeste       DF  2020-04       1024          27
# 3  Centro-Oeste       DF  2020-05       8424         140
# 4  Centro-Oeste       DF  2020-06      39438         417

# %%
import matplotlib.pyplot as plt
import string
import seaborn as sns

plt.rc('figure', figsize = (8, 6))
dfresumo = dfregiaouf[['UF_SIGLA','QTD_CASOS', 'QTD_OBITOS']].groupby('UF_SIGLA').sum()

x= np.log(dfresumo['QTD_CASOS'])
y= np.log(dfresumo['QTD_OBITOS'])
l = dfresumo.index
s = dfresumo['QTD_OBITOS'] 

fig , ax1 = plt.subplots()

sns.scatterplot(x=x, y=y, ax=ax1, size=s , hue=l, sizes=(1, 10000), legend=False )
ax1.set_title('Casos X Obitos por COVID-19 no Brasil (Em milhares)')
ax1.set_ylabel('Log(Quant. Óbitos)')
ax1.set_xlabel('Log(Quant. Casos)')

for l1, x1, y1 in zip(l, x, y):
  ax1.annotate(l1, xy=(x1,y1),
               xytext=(5,-5),
               textcoords='offset points')
  
plt.show()

# %%
dfregiaouf.head()
# Out:
#          REGIAO UF_SIGLA      MÊS  QTD_CASOS  QTD_OBITOS
# 0  Centro-Oeste       DF  2020-02          0           0
# 1  Centro-Oeste       DF  2020-03        332           3
# 2  Centro-Oeste       DF  2020-04       1024          27
# 3  Centro-Oeste       DF  2020-05       8424         140
# 4  Centro-Oeste       DF  2020-06      39438         417

# %%
dfregiaouf[['MÊS','QTD_CASOS', 'QTD_OBITOS']].groupby('MÊS').sum().plot(figsize=(6, 4))

# %%
import pandas as pd
dfcovid = pd.read_csv(nome_arquivo_covid, sep=';')
dfcovid.head()
# Out:
#    regiao estado  ... emAcompanhamentoNovos  interior/metropolitana
# 0  Brasil    NaN  ...                   NaN                     NaN
# 1  Brasil    NaN  ...                   NaN                     NaN
# 2  Brasil    NaN  ...                   NaN                     NaN
# 3  Brasil    NaN  ...                   NaN                     NaN
# 4  Brasil    NaN  ...                   NaN                     NaN
#
# [5 rows x 17 columns]

# %%
filtro = (dfcovid['estado'].isna() == False ) & ( dfcovid['codmun'].isna()  )
dfcovid = dfcovid[filtro][['regiao', 'estado', 'data' , 'casosNovos', 'obitosNovos']]

dfcovid['mes'] = dfcovid['data'].map(lambda x : x[:7])


print(dfcovid.shape)
dfcovid.head()
# Out:
# (8046, 6)
#     regiao estado        data  casosNovos  obitosNovos      mes
# 298  Norte     RO  2020-02-25           0            0  2020-02
# 299  Norte     RO  2020-02-26           0            0  2020-02
# 300  Norte     RO  2020-02-27           0            0  2020-02
# 301  Norte     RO  2020-02-28           0            0  2020-02
# 302  Norte     RO  2020-02-29           0            0  2020-02

# %%
dfcovid[['data','casosNovos']].groupby('data').sum().plot(figsize=(10, 6))

# %%
dfcovid[['data','obitosNovos']].groupby('data').sum().plot(figsize=(10, 6))

# %%
dfregiaouf[['MÊS','QTD_CASOS', 'QTD_OBITOS']].groupby('MÊS').sum().plot(figsize=(6, 4), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f15cffb3cf8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f15cfdcca90>],
#       dtype=object)

# %%
dfregiaouf[['MÊS','QTD_CASOS', 'QTD_OBITOS']].groupby('MÊS').sum().plot(kind='bar',figsize=(6, 4))

# %%
dfregiaouf[['MÊS','QTD_CASOS', 'QTD_OBITOS']].groupby('MÊS').sum().plot(kind='bar',figsize=(6, 4), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f15b6b8f278>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f15cfca88d0>],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import numpy as np

dfresumo = dfregiaouf[['MÊS','QTD_CASOS', 'QTD_OBITOS']].groupby('MÊS').sum()
xmeses = dfresumo.index
ycasos = dfresumo['QTD_CASOS']
yobitos = dfresumo['QTD_OBITOS']
plt.figure(figsize=[12,8])
plt.subplot(2, 1, 1)
plt.plot(xmeses,ycasos)
plt.title("Quantidade de Casos")

plt.subplot(2, 1, 2)
plt.plot(xmeses,yobitos)
plt.title("Quantidade de Óbitos")


plt.suptitle("Dados da Covid-19 no Brasil")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["figure.figsize"] = [6, 4]

dfresumo = dfregiaouf[['MÊS','QTD_CASOS', 'QTD_OBITOS']].groupby('MÊS').sum()

x= dfresumo.index
y= dfresumo['QTD_CASOS']

fig = sns.lineplot(x=x, y=y, marker='o', linestyle='dashed')

y= dfresumo['QTD_OBITOS']
fig = sns.lineplot(x=x, y=y, marker='o', linestyle='dashed')

plt.title('Evolução dos Casos de COVID-19 no Brasil (Em milhares)')
plt.xlabel('Mês')
plt.ylabel('Quantidade')
plt.ylim(bottom=0)
plt.xticks(rotation=90)
plt.show()

# %%
dfcomplentocompbrasil.head()
# Out:
#                        AREA_TERRIT_KM2  ...  VALOR_TRANSFERENCIAS
# REGIAO       UF_SIGLA                   ...
# Centro-Oeste DF               0.067692  ...              1.903037
#              GO               3.997550  ...              3.601271
#              MS               4.196629  ...              1.952972
#              MT              10.613109  ...              4.015254
# Nordeste     AL               0.327172  ...              1.561275
#
# [5 rows x 9 columns]

# %%
dfcomplentocompregiao.head(27)
# Out:
#                        AREA_TERRIT_KM2  ...  VALOR_TRANSFERENCIAS
# REGIAO       UF_SIGLA                   ...
# Centro-Oeste DF               0.358633  ...             16.587763
#              GO              21.179095  ...             31.390372
#              MS              22.233819  ...             17.023021
#              MT              56.228453  ...             34.998844
# Nordeste     AL               1.793834  ...              6.880064
#              BA              36.385287  ...             24.091226
#              CE               9.592682  ...             14.519699
#              MA              21.237546  ...             11.718228
#              PB               3.637962  ...              7.612206
#              PE               6.318127  ...             15.968701
#              PI              16.219680  ...              6.479903
#              RN               3.402314  ...              6.996673
#              SE               1.412569  ...              5.733302
# Norte        AC               4.262396  ...              8.367822
#              AM              40.492504  ...             20.151513
#              AP               3.700049  ...             10.249637
#              PA              32.355995  ...             31.160808
#              RO               6.174903  ...             10.967982
#              RR               5.808179  ...              9.440444
#              TO               7.205974  ...              9.661795
# Sudeste      ES               4.983362  ...              6.317827
#              MG              63.437489  ...             23.972571
#              RJ               4.731999  ...             16.824465
#              SP              26.847150  ...             52.885137
# Sul          PR              34.556313  ...             35.672023
#              RS              48.845010  ...             39.811126
#              SC              16.598677  ...             24.516851
#
# [27 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(14.7,8.27)})

dados  = dfcomplentocompregiao.to_numpy()
estados = dfcomplentocompregiao.index
variavel =  dfcomplentocompregiao.columns
fig = sns.heatmap(dados,linewidths=.5,annot=True, fmt=".2f", cmap = 'magma_r',
                  xticklabels = variavel, yticklabels = estados)
sns.cubehelix_palette(as_cmap=True, reverse=True)
plt.title('Evolução dos Casos de COVID-19 no Brasil (Em milhares)')
plt.xlabel('Variável')
plt.ylabel('Estados')
plt.show()
